# %%
import sympy as sp
from multipie import Group

# %%
tag = "MPG:8.5.28"
group = Group(tag)

# %%
group.info
# Out:
# MPGInfoType(tag='8.5.28', international="m'm'm'", schoenflies='D2h', crystal='orthorhombic', setting='', PG='PG:8', SG='SG:47', MPG='MPG:8.5.28', MSG='MSG:47.253', lattice='0', hexagonal_g=False, type='III', SO=['1', '2[100]', '2[010]', '2[001]', "-1'", "m'[100]", "m'[010]", "m'[001]"])

# %%
group.latex(detail=True)
# Out:
# "MPG No. 8.5.28\\quad$m'm'm'$\\quad[ Type III, orthorhombic ]"

# %%
for i in group.symmetry_operation["tag"]:
    display(sp.Symbol(group.tag_symmetry_operation(i, latex=True)))
# Out:
# 1
# 2{}_{100}
# 2{}_{010}
# 2{}_{001}
# -1{}'
# {\rm m}_{100}{}'
# {\rm m}_{010}{}'
# {\rm m}_{001}{}'

# %%
tag = "MSG:47.253"
group = Group(tag)

# %%
group.info
# Out:
# MSGInfoType(tag='47.253', BNS="Pm'm'm'", OG="Pm'm'm'", schoenflies='D2h^1', crystal='orthorhombic', setting='', PG='PG:8', SG='SG:47', MPG='MPG:8.5.28', MSG='MSG:47.253', lattice='P', hexagonal_g=False, type='III', SO=['1:[0,0,0]', '2[100]:[0,0,0]', '2[010]:[0,0,0]', '2[001]:[0,0,0]', "-1':[0,0,0]", "m'[100]:[0,0,0]", "m'[010]:[0,0,0]", "m'[001]:[0,0,0]"])

# %%
group.latex(detail=True)
# Out:
# "MSG No. 47.253\\quad$Pm'm'm'$\\quad[ Type III, orthorhombic ]"

# %%
for i in group.symmetry_operation["tag"]:
    display(sp.Symbol(group.tag_symmetry_operation(i, latex=True)))
# Out:
# \{1|0\}
# \{2{}_{100}|0\}
# \{2{}_{010}|0\}
# \{2{}_{001}|0\}
# \{-1{}'|0\}
# \{{\rm m}_{100}{}'|0\}
# \{{\rm m}_{010}{}'|0\}
# \{{\rm m}_{001}{}'|0\}
