# %%
"""
Check for info binary.
"""
import sympy as sp
from multipie.util.util_binary import BinaryManager
from multipie.core.multipie_info import __top_dir__
BIN_DIR = __top_dir__ + "others/tools/binary_data"
info = BinaryManager("info", verbose=True, topdir=BIN_DIR)
# Out:
# load binary from '/Users/hk/Library/CloudStorage/Dropbox/working/GitHub/MultiPie/others/tools/binary_data/info.pkl'.
# """
# * Information of all groups.
# - "id_set" (str): (dict) info. of group's IDs.
#   - "PG/SG/MPG/MSG" (str):  (dict) ID set.
#     - PG: all/crystal/complex/irrep.
#     - SG: all/crystal/PG.
#     - MPG: all/crystal/PG/type.
#     - MSG: all/crystal/PG/SG/MPG/type.
# - "tag" (str): (dict) from id to tag.
# - "id" (str):  (dict) from tag to id.
# - "character" (str): (dict) info. of character.
#   - "alias" (str): (dict) alias.
#     - "wp/wm" (str): (sympy) definition of wp and wm, exp(2 pi i/3) or exp(-2 pi i/3).
#   - "compatibility_relation" (str): (dict) compatibility relation.
#     - (PG_tag1,PG_tag2) (str,str): ([(str,str)]) list of compatibility relation, (irrep1,irrep2).
# - "root_cluster" (str): (dict) info. of root cluster.
#   - "point_group" (str): ([str]) list of PG_tag for root cluster.
#   - "rep_site_c" (str): (ndarray(3,sympy)) representative site (fractional for cubic, r=1; = cartesian).
#   - "rep_site_h" (str): (ndarray(3,sympy)) representative site (fractional for hexagonal).
#   - "scaled_rep_site_c" (str): (ndarray(3,sympy)) scaled representative site (fractional for cubic, r=1/5; = cartesian).
#   - "scaled_rep_site_h" (str): (ndarray(3,sympy)) scaled representative site (fractional for hexagonal).
#   - "rep_vector_c" (str): (ndarray(3,sympy)) representative vector (fractional for cubic, v=1; = cartesian).
#   - "rep_vector_h" (str): (ndarray(3,sympy)) representative vector (fractional for hexagonal).
# - "harmonics" (str): (dict) info. of harmonics.
#   - "max_rank" (str): (int) max rank of harmonics.
#   - "max_s_rank" (str): (int) max internal rank.
#   - "variable" (str): (ndarray(3,sympy)) coordinate variable, [x,y,z].
#   - "internal_basis" (str): (Dict) internal basis.
#     - (s,x) (int,str): (ndarray(2s+1,sympy)) list of basis.
#   - "atomic_basis" (str): (dict) atomic basis.
#     - "spinless" (str): (dict) spinless basis.
#       - "lm/lg" (str): (dict) basis.
#         - L (int): ([str]) list of basis, M or gamma.
#     - "spinful" (str): (dict) spinful basis.
#       - "jml/lms/lgs" (str): (dict) basis.
#         - L (int): ([str]) list of basis, (J,M) or (M,s) or (gamma,s).
#   - "basis_function" (str): (dict) orbital basis function.
#     - name (str): ((sympy,ndarray(2L+1,sympy))) cartesian expression and u-matrix, <m|gamma>.T.
#   - "wannier90" (str): (dict) alias for Wannier90.
#     - tag (str): (str) name corresponding to Wannier90 tag.
#   - "tesseral" (str): (dict) tesseral tag.
#     - name (str): ((int,int,str)) tesseral tag (L,M,"c/s").
#   - "rank_name" (str): (dict) conversion between rank and name.
#     - name/rank (str/int): (int/str) rank/name.
#   - "orbital_decomposition" (str): (dict) spherical harmonics irrep. decomposition.
#     - PG_tag (str): (dict) spherical harmonics irrep. decomposition for each PG.
#       - L (int): ([(int,str)]) list of (n,irrep).
#   NOTE:
#     - see "multipie/data/data_definition.py" for detail.
# - "response_tensor" (str): (dict) info. of response tensor.
#   - "multipole" (str): (dict) multipole info.
#     - "cubic/hexagonal" (str): ([str]) list of multipoles.
#   - "cartesian_multipole" (str): (dict) linear combination info.
#     - "cubic/hexagonal" (str): { comp (str): ([(int,str)]) }, relation between cartesian component and multipole.
# """

# %%
info.keys()
# Out:
# dict_keys(['id_set', 'tag', 'id', 'character', 'root_cluster', 'harmonics', 'response_tensor'])

# %%
info["harmonics"]
# Out:
# {'max_rank': 11,
#  'max_s_rank': 3,
#  'variable': (x, y, z),
#  'internal_basis': {(0, 'q'): [Q_0], (1, 'q'): [Q_x, Q_y, Q_z], (2, 'q'): [Q_v, Q_xy, Q_xz, Q_yz, Q_u], (3, 'q'): [Q_2, Q_1, Q_bz, Q_3, Q_3x, Q_3y, Q_az], (0, 'g'): [G_0], (1, 'g'): [G_x, G_y, G_z], (2, 'g'): [G_v, G_xy, G_xz, G_yz, G_u], (3, 'g'): [G_2, G_1, G_bz, G_3, G_3x, G_3y, G_az]},
#  'atomic_basis': {'spinless': {'lm': {0: ['0'],
#     1: ['1', '0', '-1'],
#     2: ['2', '1', '0', '-1', '-2'],
#     3: ['3', '2', '1', '0', '-1', '-2', '-3']},
#    'lg': {0: ['s'],
#     1: ['px', 'py', 'pz'],
#     2: ['dv', 'dxy', 'dxz', 'dyz', 'du'],
#     3: ['f2', 'f1', 'fbz', 'f3', 'f3x', 'f3y', 'faz']},
#    'cubic': {0: ['s'],
#     1: ['px', 'py', 'pz'],
#     2: ['du', 'dv', 'dyz', 'dxz', 'dxy'],
#     3: ['f3', 'fax', 'fay', 'faz', 'fbx', 'fby', 'fbz']},
#    'hexagonal': {0: ['s'],
#     1: ['px', 'py', 'pz'],
#     2: ['du', 'dxz', 'dyz', 'dxy', 'dv'],
#     3: ['faz', 'f1', 'f2', 'f3x', 'f3y', 'f3', 'fbz']}},
#   'spinful': {'jml': {0: ['(1/2,1/2)', '(1/2,-1/2)'],
#     1: ['(1/2,1/2)',
#      '(1/2,-1/2)',
#      '(3/2,3/2)',
#      '(3/2,1/2)',
#      '(3/2,-1/2)',
#      '(3/2,-3/2)'],
#     2: ['(3/2,3/2)',
#      '(3/2,1/2)',
#      '(3/2,-1/2)',
#      '(3/2,-3/2)',
#      '(5/2,5/2)',
#      '(5/2,3/2)',
#      '(5/2,1/2)',
#      '(5/2,-1/2)',
#      '(5/2,-3/2)',
#      '(5/2,-5/2)'],
#     3: ['(5/2,5/2)',
#      '(5/2,3/2)',
#      '(5/2,1/2)',
#      '(5/2,-1/2)',
#      '(5/2,-3/2)',
#      '(5/2,-5/2)',
#      '(7/2,7/2)',
#      '(7/2,5/2)',
#      '(7/2,3/2)',
#      '(7/2,1/2)',
#      '(7/2,-1/2)',
#      '(7/2,-3/2)',
#      '(7/2,-5/2)',
#      '(7/2,-7/2)']},
#    'lms': {0: ['(0,u)', '(0,d)'],
#     1: ['(1,u)', '(1,d)', '(0,u)', '(0,d)', '(-1,u)', '(-1,d)'],
#     2: ['(2,u)',
#      '(2,d)',
#      '(1,u)',
#      '(1,d)',
#      '(0,u)',
#      '(0,d)',
#      '(-1,u)',
#      '(-1,d)',
#      '(-2,u)',
#      '(-2,d)'],
#     3: ['(3,u)',
#      '(3,d)',
#      '(2,u)',
#      '(2,d)',
#      '(1,u)',
#      '(1,d)',
#      '(0,u)',
#      '(0,d)',
#      '(-1,u)',
#      '(-1,d)',
#      '(-2,u)',
#      '(-2,d)',
#      '(-3,u)',
#      '(-3,d)']},
#    'lgs': {0: ['(s,u)', '(s,d)'],
#     1: ['(px,u)', '(px,d)', '(py,u)', '(py,d)', '(pz,u)', '(pz,d)'],
#     2: ['(dv,u)',
#      '(dv,d)',
#      '(dxy,u)',
#      '(dxy,d)',
#      '(dxz,u)',
#      '(dxz,d)',
#      '(dyz,u)',
#      '(dyz,d)',
#      '(du,u)',
#      '(du,d)'],
#     3: ['(f2,u)',
#      '(f2,d)',
#      '(f1,u)',
#      '(f1,d)',
#      '(fbz,u)',
#      '(fbz,d)',
#      '(f3,u)',
#      '(f3,d)',
#      '(f3x,u)',
#      '(f3x,d)',
#      '(f3y,u)',
#      '(f3y,d)',
#      '(faz,u)',
#      '(faz,d)']},
#    'cubic': {0: ['(s,u)', '(s,d)'],
#     1: ['(px,u)', '(px,d)', '(py,u)', '(py,d)', '(pz,u)', '(pz,d)'],
#     2: ['(du,u)',
#      '(du,d)',
#      '(dv,u)',
#      '(dv,d)',
#      '(dyz,u)',
#      '(dyz,d)',
#      '(dxz,u)',
#      '(dxz,d)',
#      '(dxy,u)',
#      '(dxy,d)'],
#     3: ['(f3,u)',
#      '(f3,d)',
#      '(fax,u)',
#      '(fax,d)',
#      '(fay,u)',
#      '(fay,d)',
#      '(faz,u)',
#      '(faz,d)',
#      '(fbx,u)',
#      '(fbx,d)',
#      '(fby,u)',
#      '(fby,d)',
#      '(fbz,u)',
#      '(fbz,d)']},
#    'hexagonal': {0: ['(s,u)', '(s,d)'],
#     1: ['(px,u)', '(px,d)', '(py,u)', '(py,d)', '(pz,u)', '(pz,d)'],
#     2: ['(du,u)',
#      '(du,d)',
#      '(dxz,u)',
#      '(dxz,d)',
#      '(dyz,u)',
#      '(dyz,d)',
#      '(dxy,u)',
#      '(dxy,d)',
#      '(dv,u)',
#      '(dv,d)'],
#     3: ['(faz,u)',
#      '(faz,d)',
#      '(f1,u)',
#      '(f1,d)',
#      '(f2,u)',
#      '(f2,d)',
#      '(f3x,u)',
#      '(f3x,d)',
#      '(f3y,u)',
#      '(f3y,d)',
#      '(f3,u)',
#      '(f3,d)',
#      '(fbz,u)',
#      '(fbz,d)']}}},
#  'rank_name': {0: 'monopole',
#   1: 'dipole',
#   2: 'quadrupole',
#   3: 'octupole',
#   4: 'hexadecapole',
#   5: 'dotriacontapole',
#   6: 'tetrahexacontapole',
#   'monopole': 0,
#   'dipole': 1,
#   'quadrupole': 2,
#   'octupole': 3,
#   'hexadecapole': 4,
#   'dotriacontapole': 5,
#   'tetrahexacontapole': 6},
#  'wannier90': {'dx2-y2': 'dv',
#   'dz2': 'du',
#   'fx(x2-3y2)': 'f2',
#   'fy(3x2-y2)': 'f1',
#   'fz(x2-y2)': 'fbz',
#   'fxyz': 'f3',
#   'fxz2': 'f3x',
#   'fyz2': 'f3y',
#   'fz3': 'faz'},
#  'tesseral': {'s': (0, 0, 'c'),
#   'px': (1, 1, 'c'),
#   'py': (1, 1, 's'),
#   'pz': (1, 0, 'c'),
#   'dv': (2, 2, 'c'),
#   'dxy': (2, 2, 's'),
#   'dxz': (2, 1, 'c'),
#   'dyz': (2, 1, 's'),
#   'du': (2, 0, 'c'),
#   'f2': (3, 3, 'c'),
#   'f1': (3, 3, 's'),
#   'fbz': (3, 2, 'c'),
#   'f3': (3, 2, 's'),
#   'f3x': (3, 1, 'c'),
#   'f3y': (3, 1, 's'),
#   'faz': (3, 0, 'c')},
#  'basis_function': {'s': (1, array([1], dtype=object)),
#   'px': (x, array([-sqrt(2)/2, 0, sqrt(2)/2], dtype=object)),
#   'py': (y, array([sqrt(2)*I/2, 0, sqrt(2)*I/2], dtype=object)),
#   'pz': (z, array([0, 1, 0], dtype=object)),
#   'du': (-x**2/2 - y**2/2 + z**2, array([0, 0, 1, 0, 0], dtype=object)),
#   'dv': (sqrt(3)*(x**2 - y**2)/2,
#    array([sqrt(2)/2, 0, 0, 0, sqrt(2)/2], dtype=object)),
#   'dyz': (sqrt(3)*y*z,
#    array([0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0], dtype=object)),
#   'dxz': (sqrt(3)*x*z, array([0, -sqrt(2)/2, 0, sqrt(2)/2, 0], dtype=object)),
#   'dxy': (sqrt(3)*x*y,
#    array([-sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2], dtype=object)),
#   'f3': (sqrt(15)*x*y*z,
#    array([0, -sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2, 0], dtype=object)),
#   'fax': (x*(2*x**2 - 3*y**2 - 3*z**2)/2,
#    array([-sqrt(5)/4, 0, sqrt(3)/4, 0, -sqrt(3)/4, 0, sqrt(5)/4],
#          dtype=object)),
#   'fay': (y*(-3*x**2 + 2*y**2 - 3*z**2)/2,
#    array([-sqrt(5)*I/4, 0, -sqrt(3)*I/4, 0, -sqrt(3)*I/4, 0, -sqrt(5)*I/4],
#          dtype=object)),
#   'faz': (z*(-3*x**2 - 3*y**2 + 2*z**2)/2,
#    array([0, 0, 0, 1, 0, 0, 0], dtype=object)),
#   'fbx': (sqrt(15)*x*(y**2 - z**2)/2,
#    array([sqrt(3)/4, 0, sqrt(5)/4, 0, -sqrt(5)/4, 0, -sqrt(3)/4],
#          dtype=object)),
#   'fby': (sqrt(15)*y*(-x**2 + z**2)/2,
#    array([-sqrt(3)*I/4, 0, sqrt(5)*I/4, 0, sqrt(5)*I/4, 0, -sqrt(3)*I/4],
#          dtype=object)),
#   'fbz': (sqrt(15)*z*(x**2 - y**2)/2,
#    array([0, sqrt(2)/2, 0, 0, 0, sqrt(2)/2, 0], dtype=object)),
#   'f1': (sqrt(10)*y*(3*x**2 - y**2)/4,
#    array([sqrt(2)*I/2, 0, 0, 0, 0, 0, sqrt(2)*I/2], dtype=object)),
#   'f2': (sqrt(10)*x*(x**2 - 3*y**2)/4,
#    array([-sqrt(2)/2, 0, 0, 0, 0, 0, sqrt(2)/2], dtype=object)),
#   'f3x': (sqrt(6)*x*(-x**2 - y**2 + 4*z**2)/4,
#    array([0, 0, -sqrt(2)/2, 0, sqrt(2)/2, 0, 0], dtype=object)),
#   'f3y': (sqrt(6)*y*(-x**2 - y**2 + 4*z**2)/4,
#    array([0, 0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0, 0], dtype=object)),
#   'g': (sqrt(21)*(x**4 - 3*x**2*y**2 - 3*x**2*z**2 + y**4 - 3*y**2*z**2 + z**4)/6,
#    array([sqrt(30)/12, 0, 0, 0, sqrt(21)/6, 0, 0, 0, sqrt(30)/12],
#          dtype=object)),
#   'gu': (-sqrt(15)*(x**4 - 12*x**2*y**2 + 6*x**2*z**2 + y**4 + 6*y**2*z**2 - 2*z**4)/12,
#    array([-sqrt(42)/12, 0, 0, 0, sqrt(15)/6, 0, 0, 0, -sqrt(42)/12],
#          dtype=object)),
#   'gv': (sqrt(5)*(x - y)*(x + y)*(-x**2 - y**2 + 6*z**2)/4,
#    array([0, 0, sqrt(2)/2, 0, 0, 0, sqrt(2)/2, 0, 0], dtype=object)),
#   'gax': (sqrt(35)*y*z*(y - z)*(y + z)/2,
#    array([0, -I/4, 0, -sqrt(7)*I/4, 0, -sqrt(7)*I/4, 0, -I/4, 0],
#          dtype=object)),
#   'gay': (sqrt(35)*x*z*(-x + z)*(x + z)/2,
#    array([0, 1/4, 0, -sqrt(7)/4, 0, sqrt(7)/4, 0, -1/4, 0], dtype=object)),
#   'gaz': (sqrt(35)*x*y*(x - y)*(x + y)/2,
#    array([-sqrt(2)*I/2, 0, 0, 0, 0, 0, 0, 0, sqrt(2)*I/2], dtype=object)),
#   'gbx': (sqrt(5)*y*z*(6*x**2 - y**2 - z**2)/2,
#    array([0, sqrt(7)*I/4, 0, -I/4, 0, -I/4, 0, sqrt(7)*I/4, 0], dtype=object)),
#   'gby': (sqrt(5)*x*z*(-x**2 + 6*y**2 - z**2)/2,
#    array([0, sqrt(7)/4, 0, 1/4, 0, -1/4, 0, -sqrt(7)/4, 0], dtype=object)),
#   'gbz': (sqrt(5)*x*y*(-x**2 - y**2 + 6*z**2)/2,
#    array([0, 0, -sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2, 0, 0], dtype=object)),
#   'g0': (3*x**4/8 + 3*x**2*y**2/4 - 3*x**2*z**2 + 3*y**4/8 - 3*y**2*z**2 + z**4,
#    array([0, 0, 0, 0, 1, 0, 0, 0, 0], dtype=object)),
#   'ga': (sqrt(70)*x*z*(x**2 - 3*y**2)/4,
#    array([0, -sqrt(2)/2, 0, 0, 0, 0, 0, sqrt(2)/2, 0], dtype=object)),
#   'gb': (sqrt(70)*y*z*(3*x**2 - y**2)/4,
#    array([0, sqrt(2)*I/2, 0, 0, 0, 0, 0, sqrt(2)*I/2, 0], dtype=object)),
#   'gc': (sqrt(35)*(x**2 - 2*x*y - y**2)*(x**2 + 2*x*y - y**2)/8,
#    array([sqrt(2)/2, 0, 0, 0, 0, 0, 0, 0, sqrt(2)/2], dtype=object)),
#   'gau': (-sqrt(10)*y*z*(3*x**2 + 3*y**2 - 4*z**2)/4,
#    array([0, 0, 0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0, 0, 0], dtype=object)),
#   'gav': (sqrt(10)*x*z*(3*x**2 + 3*y**2 - 4*z**2)/4,
#    array([0, 0, 0, sqrt(2)/2, 0, -sqrt(2)/2, 0, 0, 0], dtype=object))},
#  'orbital_decomposition': {'C1': {0: [(1, 'A')],
#    1: [(3, 'A')],
#    2: [(5, 'A')],
#    3: [(7, 'A')],
#    4: [(9, 'A')],
#    5: [(11, 'A')],
#    6: [(13, 'A')],
#    7: [(15, 'A')],
#    8: [(17, 'A')],
#    9: [(19, 'A')],
#    10: [(21, 'A')],
#    11: [(23, 'A')]},
#   'Ci': {0: [(1, 'Ag')],
#    1: [(3, 'Au')],
#    2: [(5, 'Ag')],
#    3: [(7, 'Au')],
#    4: [(9, 'Ag')],
#    5: [(11, 'Au')],
#    6: [(13, 'Ag')],
#    7: [(15, 'Au')],
#    8: [(17, 'Ag')],
#    9: [(19, 'Au')],
#    10: [(21, 'Ag')],
#    11: [(23, 'Au')]},
#   'C2': {0: [(1, 'A')],
#    1: [(1, 'A'), (2, 'B')],
#    2: [(3, 'A'), (2, 'B')],
#    3: [(3, 'A'), (4, 'B')],
#    4: [(5, 'A'), (4, 'B')],
#    5: [(5, 'A'), (6, 'B')],
#    6: [(7, 'A'), (6, 'B')],
#    7: [(7, 'A'), (8, 'B')],
#    8: [(9, 'A'), (8, 'B')],
#    9: [(9, 'A'), (10, 'B')],
#    10: [(11, 'A'), (10, 'B')],
#    11: [(11, 'A'), (12, 'B')]},
#   'Cs': {0: [(1, "A'")],
#    1: [(2, "A'"), (1, "A''")],
#    2: [(3, "A'"), (2, "A''")],
#    3: [(4, "A'"), (3, "A''")],
#    4: [(5, "A'"), (4, "A''")],
#    5: [(6, "A'"), (5, "A''")],
#    6: [(7, "A'"), (6, "A''")],
#    7: [(8, "A'"), (7, "A''")],
#    8: [(9, "A'"), (8, "A''")],
#    9: [(10, "A'"), (9, "A''")],
#    10: [(11, "A'"), (10, "A''")],
#    11: [(12, "A'"), (11, "A''")]},
#   'C2h': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (2, 'Bu')],
#    2: [(3, 'Ag'), (2, 'Bg')],
#    3: [(3, 'Au'), (4, 'Bu')],
#    4: [(5, 'Ag'), (4, 'Bg')],
#    5: [(5, 'Au'), (6, 'Bu')],
#    6: [(7, 'Ag'), (6, 'Bg')],
#    7: [(7, 'Au'), (8, 'Bu')],
#    8: [(9, 'Ag'), (8, 'Bg')],
#    9: [(9, 'Au'), (10, 'Bu')],
#    10: [(11, 'Ag'), (10, 'Bg')],
#    11: [(11, 'Au'), (12, 'Bu')]},
#   'D2': {0: [(1, 'A')],
#    1: [(1, 'B1'), (1, 'B2'), (1, 'B3')],
#    2: [(2, 'A'), (1, 'B1'), (1, 'B2'), (1, 'B3')],
#    3: [(1, 'A'), (2, 'B1'), (2, 'B2'), (2, 'B3')],
#    4: [(3, 'A'), (2, 'B1'), (2, 'B2'), (2, 'B3')],
#    5: [(2, 'A'), (3, 'B1'), (3, 'B2'), (3, 'B3')],
#    6: [(4, 'A'), (3, 'B1'), (3, 'B2'), (3, 'B3')],
#    7: [(3, 'A'), (4, 'B1'), (4, 'B2'), (4, 'B3')],
#    8: [(5, 'A'), (4, 'B1'), (4, 'B2'), (4, 'B3')],
#    9: [(4, 'A'), (5, 'B1'), (5, 'B2'), (5, 'B3')],
#    10: [(6, 'A'), (5, 'B1'), (5, 'B2'), (5, 'B3')],
#    11: [(5, 'A'), (6, 'B1'), (6, 'B2'), (6, 'B3')]},
#   'C2v': {0: [(1, 'A1')],
#    1: [(1, 'A1'), (1, 'B1'), (1, 'B2')],
#    2: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2')],
#    3: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2')],
#    4: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2')],
#    5: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2')],
#    6: [(4, 'A1'), (3, 'A2'), (3, 'B1'), (3, 'B2')],
#    7: [(4, 'A1'), (3, 'A2'), (4, 'B1'), (4, 'B2')],
#    8: [(5, 'A1'), (4, 'A2'), (4, 'B1'), (4, 'B2')],
#    9: [(5, 'A1'), (4, 'A2'), (5, 'B1'), (5, 'B2')],
#    10: [(6, 'A1'), (5, 'A2'), (5, 'B1'), (5, 'B2')],
#    11: [(6, 'A1'), (5, 'A2'), (6, 'B1'), (6, 'B2')]},
#   'D2h': {0: [(1, 'Ag')],
#    1: [(1, 'B1u'), (1, 'B2u'), (1, 'B3u')],
#    2: [(2, 'Ag'), (1, 'B1g'), (1, 'B2g'), (1, 'B3g')],
#    3: [(1, 'Au'), (2, 'B1u'), (2, 'B2u'), (2, 'B3u')],
#    4: [(3, 'Ag'), (2, 'B1g'), (2, 'B2g'), (2, 'B3g')],
#    5: [(2, 'Au'), (3, 'B1u'), (3, 'B2u'), (3, 'B3u')],
#    6: [(4, 'Ag'), (3, 'B1g'), (3, 'B2g'), (3, 'B3g')],
#    7: [(3, 'Au'), (4, 'B1u'), (4, 'B2u'), (4, 'B3u')],
#    8: [(5, 'Ag'), (4, 'B1g'), (4, 'B2g'), (4, 'B3g')],
#    9: [(4, 'Au'), (5, 'B1u'), (5, 'B2u'), (5, 'B3u')],
#    10: [(6, 'Ag'), (5, 'B1g'), (5, 'B2g'), (5, 'B3g')],
#    11: [(5, 'Au'), (6, 'B1u'), (6, 'B2u'), (6, 'B3u')]},
#   'C4': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'E')],
#    2: [(1, 'A'), (2, 'B'), (1, 'E')],
#    3: [(1, 'A'), (2, 'B'), (2, 'E')],
#    4: [(3, 'A'), (2, 'B'), (2, 'E')],
#    5: [(3, 'A'), (2, 'B'), (3, 'E')],
#    6: [(3, 'A'), (4, 'B'), (3, 'E')],
#    7: [(3, 'A'), (4, 'B'), (4, 'E')],
#    8: [(5, 'A'), (4, 'B'), (4, 'E')],
#    9: [(5, 'A'), (4, 'B'), (5, 'E')],
#    10: [(5, 'A'), (6, 'B'), (5, 'E')],
#    11: [(5, 'A'), (6, 'B'), (6, 'E')]},
#   'S4': {0: [(1, 'A')],
#    1: [(1, 'B'), (1, 'E')],
#    2: [(1, 'A'), (2, 'B'), (1, 'E')],
#    3: [(2, 'A'), (1, 'B'), (2, 'E')],
#    4: [(3, 'A'), (2, 'B'), (2, 'E')],
#    5: [(2, 'A'), (3, 'B'), (3, 'E')],
#    6: [(3, 'A'), (4, 'B'), (3, 'E')],
#    7: [(4, 'A'), (3, 'B'), (4, 'E')],
#    8: [(5, 'A'), (4, 'B'), (4, 'E')],
#    9: [(4, 'A'), (5, 'B'), (5, 'E')],
#    10: [(5, 'A'), (6, 'B'), (5, 'E')],
#    11: [(6, 'A'), (5, 'B'), (6, 'E')]},
#   'C4h': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'Eu')],
#    2: [(1, 'Ag'), (2, 'Bg'), (1, 'Eg')],
#    3: [(1, 'Au'), (2, 'Bu'), (2, 'Eu')],
#    4: [(3, 'Ag'), (2, 'Bg'), (2, 'Eg')],
#    5: [(3, 'Au'), (2, 'Bu'), (3, 'Eu')],
#    6: [(3, 'Ag'), (4, 'Bg'), (3, 'Eg')],
#    7: [(3, 'Au'), (4, 'Bu'), (4, 'Eu')],
#    8: [(5, 'Ag'), (4, 'Bg'), (4, 'Eg')],
#    9: [(5, 'Au'), (4, 'Bu'), (5, 'Eu')],
#    10: [(5, 'Ag'), (6, 'Bg'), (5, 'Eg')],
#    11: [(5, 'Au'), (6, 'Bu'), (6, 'Eu')]},
#   'D4': {0: [(1, 'A1')],
#    1: [(1, 'A2'), (1, 'E')],
#    2: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E')],
#    3: [(1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    5: [(1, 'A1'), (2, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E')],
#    6: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E')],
#    7: [(1, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    9: [(2, 'A1'), (3, 'A2'), (2, 'B1'), (2, 'B2'), (5, 'E')],
#    10: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2'), (5, 'E')],
#    11: [(2, 'A1'), (3, 'A2'), (3, 'B1'), (3, 'B2'), (6, 'E')]},
#   'C4v': {0: [(1, 'A1')],
#    1: [(1, 'A1'), (1, 'E')],
#    2: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E')],
#    3: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    5: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E')],
#    6: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E')],
#    7: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    9: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (5, 'E')],
#    10: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2'), (5, 'E')],
#    11: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2'), (6, 'E')]},
#   'D2d': {0: [(1, 'A1')],
#    1: [(1, 'B2'), (1, 'E')],
#    2: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E')],
#    3: [(1, 'A1'), (1, 'A2'), (1, 'B2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    5: [(1, 'A1'), (1, 'A2'), (1, 'B1'), (2, 'B2'), (3, 'E')],
#    6: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E')],
#    7: [(2, 'A1'), (2, 'A2'), (1, 'B1'), (2, 'B2'), (4, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    9: [(2, 'A1'), (2, 'A2'), (2, 'B1'), (3, 'B2'), (5, 'E')],
#    10: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2'), (5, 'E')],
#    11: [(3, 'A1'), (3, 'A2'), (2, 'B1'), (3, 'B2'), (6, 'E')]},
#   'D2d-1': {0: [(1, 'A1')],
#    1: [(1, 'B2'), (1, 'E')],
#    2: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E')],
#    3: [(1, 'A1'), (1, 'A2'), (1, 'B2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E')],
#    5: [(1, 'A1'), (1, 'A2'), (1, 'B1'), (2, 'B2'), (3, 'E')],
#    6: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E')],
#    7: [(2, 'A1'), (2, 'A2'), (1, 'B1'), (2, 'B2'), (4, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E')],
#    9: [(2, 'A1'), (2, 'A2'), (2, 'B1'), (3, 'B2'), (5, 'E')],
#    10: [(3, 'A1'), (2, 'A2'), (3, 'B1'), (3, 'B2'), (5, 'E')],
#    11: [(3, 'A1'), (3, 'A2'), (2, 'B1'), (3, 'B2'), (6, 'E')]},
#   'D4h': {0: [(1, 'A1g')],
#    1: [(1, 'A2u'), (1, 'Eu')],
#    2: [(1, 'A1g'), (1, 'B1g'), (1, 'B2g'), (1, 'Eg')],
#    3: [(1, 'A2u'), (1, 'B1u'), (1, 'B2u'), (2, 'Eu')],
#    4: [(2, 'A1g'), (1, 'A2g'), (1, 'B1g'), (1, 'B2g'), (2, 'Eg')],
#    5: [(1, 'A1u'), (2, 'A2u'), (1, 'B1u'), (1, 'B2u'), (3, 'Eu')],
#    6: [(2, 'A1g'), (1, 'A2g'), (2, 'B1g'), (2, 'B2g'), (3, 'Eg')],
#    7: [(1, 'A1u'), (2, 'A2u'), (2, 'B1u'), (2, 'B2u'), (4, 'Eu')],
#    8: [(3, 'A1g'), (2, 'A2g'), (2, 'B1g'), (2, 'B2g'), (4, 'Eg')],
#    9: [(2, 'A1u'), (3, 'A2u'), (2, 'B1u'), (2, 'B2u'), (5, 'Eu')],
#    10: [(3, 'A1g'), (2, 'A2g'), (3, 'B1g'), (3, 'B2g'), (5, 'Eg')],
#    11: [(2, 'A1u'), (3, 'A2u'), (3, 'B1u'), (3, 'B2u'), (6, 'Eu')]},
#   'C3': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'E')],
#    2: [(1, 'A'), (2, 'E')],
#    3: [(3, 'A'), (2, 'E')],
#    4: [(3, 'A'), (3, 'E')],
#    5: [(3, 'A'), (4, 'E')],
#    6: [(5, 'A'), (4, 'E')],
#    7: [(5, 'A'), (5, 'E')],
#    8: [(5, 'A'), (6, 'E')],
#    9: [(7, 'A'), (6, 'E')],
#    10: [(7, 'A'), (7, 'E')],
#    11: [(7, 'A'), (8, 'E')]},
#   'C3i': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'Eu')],
#    2: [(1, 'Ag'), (2, 'Eg')],
#    3: [(3, 'Au'), (2, 'Eu')],
#    4: [(3, 'Ag'), (3, 'Eg')],
#    5: [(3, 'Au'), (4, 'Eu')],
#    6: [(5, 'Ag'), (4, 'Eg')],
#    7: [(5, 'Au'), (5, 'Eu')],
#    8: [(5, 'Ag'), (6, 'Eg')],
#    9: [(7, 'Au'), (6, 'Eu')],
#    10: [(7, 'Ag'), (7, 'Eg')],
#    11: [(7, 'Au'), (8, 'Eu')]},
#   'D3': {0: [(1, 'A1')],
#    1: [(1, 'A2'), (1, 'E')],
#    2: [(1, 'A1'), (2, 'E')],
#    3: [(1, 'A1'), (2, 'A2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (3, 'E')],
#    5: [(1, 'A1'), (2, 'A2'), (4, 'E')],
#    6: [(3, 'A1'), (2, 'A2'), (4, 'E')],
#    7: [(2, 'A1'), (3, 'A2'), (5, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (6, 'E')],
#    9: [(3, 'A1'), (4, 'A2'), (6, 'E')],
#    10: [(4, 'A1'), (3, 'A2'), (7, 'E')],
#    11: [(3, 'A1'), (4, 'A2'), (8, 'E')]},
#   'D3-1': {0: [(1, 'A1')],
#    1: [(1, 'A2'), (1, 'E')],
#    2: [(1, 'A1'), (2, 'E')],
#    3: [(1, 'A1'), (2, 'A2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (3, 'E')],
#    5: [(1, 'A1'), (2, 'A2'), (4, 'E')],
#    6: [(3, 'A1'), (2, 'A2'), (4, 'E')],
#    7: [(2, 'A1'), (3, 'A2'), (5, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (6, 'E')],
#    9: [(3, 'A1'), (4, 'A2'), (6, 'E')],
#    10: [(4, 'A1'), (3, 'A2'), (7, 'E')],
#    11: [(3, 'A1'), (4, 'A2'), (8, 'E')]},
#   'C3v': {0: [(1, 'A1')],
#    1: [(1, 'A1'), (1, 'E')],
#    2: [(1, 'A1'), (2, 'E')],
#    3: [(2, 'A1'), (1, 'A2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (3, 'E')],
#    5: [(2, 'A1'), (1, 'A2'), (4, 'E')],
#    6: [(3, 'A1'), (2, 'A2'), (4, 'E')],
#    7: [(3, 'A1'), (2, 'A2'), (5, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (6, 'E')],
#    9: [(4, 'A1'), (3, 'A2'), (6, 'E')],
#    10: [(4, 'A1'), (3, 'A2'), (7, 'E')],
#    11: [(4, 'A1'), (3, 'A2'), (8, 'E')]},
#   'C3v-1': {0: [(1, 'A1')],
#    1: [(1, 'A1'), (1, 'E')],
#    2: [(1, 'A1'), (2, 'E')],
#    3: [(2, 'A1'), (1, 'A2'), (2, 'E')],
#    4: [(2, 'A1'), (1, 'A2'), (3, 'E')],
#    5: [(2, 'A1'), (1, 'A2'), (4, 'E')],
#    6: [(3, 'A1'), (2, 'A2'), (4, 'E')],
#    7: [(3, 'A1'), (2, 'A2'), (5, 'E')],
#    8: [(3, 'A1'), (2, 'A2'), (6, 'E')],
#    9: [(4, 'A1'), (3, 'A2'), (6, 'E')],
#    10: [(4, 'A1'), (3, 'A2'), (7, 'E')],
#    11: [(4, 'A1'), (3, 'A2'), (8, 'E')]},
#   'D3d': {0: [(1, 'A1g')],
#    1: [(1, 'A2u'), (1, 'Eu')],
#    2: [(1, 'A1g'), (2, 'Eg')],
#    3: [(1, 'A1u'), (2, 'A2u'), (2, 'Eu')],
#    4: [(2, 'A1g'), (1, 'A2g'), (3, 'Eg')],
#    5: [(1, 'A1u'), (2, 'A2u'), (4, 'Eu')],
#    6: [(3, 'A1g'), (2, 'A2g'), (4, 'Eg')],
#    7: [(2, 'A1u'), (3, 'A2u'), (5, 'Eu')],
#    8: [(3, 'A1g'), (2, 'A2g'), (6, 'Eg')],
#    9: [(3, 'A1u'), (4, 'A2u'), (6, 'Eu')],
#    10: [(4, 'A1g'), (3, 'A2g'), (7, 'Eg')],
#    11: [(3, 'A1u'), (4, 'A2u'), (8, 'Eu')]},
#   'D3d-1': {0: [(1, 'A1g')],
#    1: [(1, 'A2u'), (1, 'Eu')],
#    2: [(1, 'A1g'), (2, 'Eg')],
#    3: [(1, 'A1u'), (2, 'A2u'), (2, 'Eu')],
#    4: [(2, 'A1g'), (1, 'A2g'), (3, 'Eg')],
#    5: [(1, 'A1u'), (2, 'A2u'), (4, 'Eu')],
#    6: [(3, 'A1g'), (2, 'A2g'), (4, 'Eg')],
#    7: [(2, 'A1u'), (3, 'A2u'), (5, 'Eu')],
#    8: [(3, 'A1g'), (2, 'A2g'), (6, 'Eg')],
#    9: [(3, 'A1u'), (4, 'A2u'), (6, 'Eu')],
#    10: [(4, 'A1g'), (3, 'A2g'), (7, 'Eg')],
#    11: [(3, 'A1u'), (4, 'A2u'), (8, 'Eu')]},
#   'C6': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'E1')],
#    2: [(1, 'A'), (1, 'E1'), (1, 'E2')],
#    3: [(1, 'A'), (2, 'B'), (1, 'E1'), (1, 'E2')],
#    4: [(1, 'A'), (2, 'B'), (1, 'E1'), (2, 'E2')],
#    5: [(1, 'A'), (2, 'B'), (2, 'E1'), (2, 'E2')],
#    6: [(3, 'A'), (2, 'B'), (2, 'E1'), (2, 'E2')],
#    7: [(3, 'A'), (2, 'B'), (3, 'E1'), (2, 'E2')],
#    8: [(3, 'A'), (2, 'B'), (3, 'E1'), (3, 'E2')],
#    9: [(3, 'A'), (4, 'B'), (3, 'E1'), (3, 'E2')],
#    10: [(3, 'A'), (4, 'B'), (3, 'E1'), (4, 'E2')],
#    11: [(3, 'A'), (4, 'B'), (4, 'E1'), (4, 'E2')]},
#   'C3h': {0: [(1, "A'")],
#    1: [(1, "A''"), (1, "E'")],
#    2: [(1, "A'"), (1, "E'"), (1, "E''")],
#    3: [(2, "A'"), (1, "A''"), (1, "E'"), (1, "E''")],
#    4: [(1, "A'"), (2, "A''"), (2, "E'"), (1, "E''")],
#    5: [(2, "A'"), (1, "A''"), (2, "E'"), (2, "E''")],
#    6: [(3, "A'"), (2, "A''"), (2, "E'"), (2, "E''")],
#    7: [(2, "A'"), (3, "A''"), (3, "E'"), (2, "E''")],
#    8: [(3, "A'"), (2, "A''"), (3, "E'"), (3, "E''")],
#    9: [(4, "A'"), (3, "A''"), (3, "E'"), (3, "E''")],
#    10: [(3, "A'"), (4, "A''"), (4, "E'"), (3, "E''")],
#    11: [(4, "A'"), (3, "A''"), (4, "E'"), (4, "E''")]},
#   'C6h': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'E1u')],
#    2: [(1, 'Ag'), (1, 'E1g'), (1, 'E2g')],
#    3: [(1, 'Au'), (2, 'Bu'), (1, 'E1u'), (1, 'E2u')],
#    4: [(1, 'Ag'), (2, 'Bg'), (1, 'E1g'), (2, 'E2g')],
#    5: [(1, 'Au'), (2, 'Bu'), (2, 'E1u'), (2, 'E2u')],
#    6: [(3, 'Ag'), (2, 'Bg'), (2, 'E1g'), (2, 'E2g')],
#    7: [(3, 'Au'), (2, 'Bu'), (3, 'E1u'), (2, 'E2u')],
#    8: [(3, 'Ag'), (2, 'Bg'), (3, 'E1g'), (3, 'E2g')],
#    9: [(3, 'Au'), (4, 'Bu'), (3, 'E1u'), (3, 'E2u')],
#    10: [(3, 'Ag'), (4, 'Bg'), (3, 'E1g'), (4, 'E2g')],
#    11: [(3, 'Au'), (4, 'Bu'), (4, 'E1u'), (4, 'E2u')]},
#   'D6': {0: [(1, 'A1')],
#    1: [(1, 'A2'), (1, 'E1')],
#    2: [(1, 'A1'), (1, 'E1'), (1, 'E2')],
#    3: [(1, 'A2'), (1, 'B1'), (1, 'B2'), (1, 'E1'), (1, 'E2')],
#    4: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E1'), (2, 'E2')],
#    5: [(1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E1'), (2, 'E2')],
#    6: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E1'), (2, 'E2')],
#    7: [(1, 'A1'), (2, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E1'), (2, 'E2')],
#    8: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E1'), (3, 'E2')],
#    9: [(1, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E1'), (3, 'E2')],
#    10: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E1'), (4, 'E2')],
#    11: [(1, 'A1'), (2, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E1'), (4, 'E2')]},
#   'C6v': {0: [(1, 'A1')],
#    1: [(1, 'A1'), (1, 'E1')],
#    2: [(1, 'A1'), (1, 'E1'), (1, 'E2')],
#    3: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E1'), (1, 'E2')],
#    4: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (1, 'E1'), (2, 'E2')],
#    5: [(1, 'A1'), (1, 'B1'), (1, 'B2'), (2, 'E1'), (2, 'E2')],
#    6: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (2, 'E1'), (2, 'E2')],
#    7: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E1'), (2, 'E2')],
#    8: [(2, 'A1'), (1, 'A2'), (1, 'B1'), (1, 'B2'), (3, 'E1'), (3, 'E2')],
#    9: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E1'), (3, 'E2')],
#    10: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (3, 'E1'), (4, 'E2')],
#    11: [(2, 'A1'), (1, 'A2'), (2, 'B1'), (2, 'B2'), (4, 'E1'), (4, 'E2')]},
#   'D3h': {0: [(1, "A1'")],
#    1: [(1, "A2''"), (1, "E'")],
#    2: [(1, "A1'"), (1, "E'"), (1, "E''")],
#    3: [(1, "A1'"), (1, "A2'"), (1, "A2''"), (1, "E'"), (1, "E''")],
#    4: [(1, "A1'"), (1, "A1''"), (1, "A2''"), (2, "E'"), (1, "E''")],
#    5: [(1, "A1'"), (1, "A2'"), (1, "A2''"), (2, "E'"), (2, "E''")],
#    6: [(2, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (1, "A2''"),
#     (2, "E'"),
#     (2, "E''")],
#    7: [(1, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (2, "A2''"),
#     (3, "E'"),
#     (2, "E''")],
#    8: [(2, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (1, "A2''"),
#     (3, "E'"),
#     (3, "E''")],
#    9: [(2, "A1'"),
#     (1, "A1''"),
#     (2, "A2'"),
#     (2, "A2''"),
#     (3, "E'"),
#     (3, "E''")],
#    10: [(2, "A1'"),
#     (2, "A1''"),
#     (1, "A2'"),
#     (2, "A2''"),
#     (4, "E'"),
#     (3, "E''")],
#    11: [(2, "A1'"),
#     (1, "A1''"),
#     (2, "A2'"),
#     (2, "A2''"),
#     (4, "E'"),
#     (4, "E''")]},
#   'D3h-1': {0: [(1, "A1'")],
#    1: [(1, "A2''"), (1, "E'")],
#    2: [(1, "A1'"), (1, "E'"), (1, "E''")],
#    3: [(1, "A1'"), (1, "A2'"), (1, "A2''"), (1, "E'"), (1, "E''")],
#    4: [(1, "A1'"), (1, "A1''"), (1, "A2''"), (2, "E'"), (1, "E''")],
#    5: [(1, "A1'"), (1, "A2'"), (1, "A2''"), (2, "E'"), (2, "E''")],
#    6: [(2, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (1, "A2''"),
#     (2, "E'"),
#     (2, "E''")],
#    7: [(1, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (2, "A2''"),
#     (3, "E'"),
#     (2, "E''")],
#    8: [(2, "A1'"),
#     (1, "A1''"),
#     (1, "A2'"),
#     (1, "A2''"),
#     (3, "E'"),
#     (3, "E''")],
#    9: [(2, "A1'"),
#     (1, "A1''"),
#     (2, "A2'"),
#     (2, "A2''"),
#     (3, "E'"),
#     (3, "E''")],
#    10: [(2, "A1'"),
#     (2, "A1''"),
#     (1, "A2'"),
#     (2, "A2''"),
#     (4, "E'"),
#     (3, "E''")],
#    11: [(2, "A1'"),
#     (1, "A1''"),
#     (2, "A2'"),
#     (2, "A2''"),
#     (4, "E'"),
#     (4, "E''")]},
#   'D6h': {0: [(1, 'A1g')],
#    1: [(1, 'A2u'), (1, 'E1u')],
#    2: [(1, 'A1g'), (1, 'E1g'), (1, 'E2g')],
#    3: [(1, 'A2u'), (1, 'B1u'), (1, 'B2u'), (1, 'E1u'), (1, 'E2u')],
#    4: [(1, 'A1g'), (1, 'B1g'), (1, 'B2g'), (1, 'E1g'), (2, 'E2g')],
#    5: [(1, 'A2u'), (1, 'B1u'), (1, 'B2u'), (2, 'E1u'), (2, 'E2u')],
#    6: [(2, 'A1g'), (1, 'A2g'), (1, 'B1g'), (1, 'B2g'), (2, 'E1g'), (2, 'E2g')],
#    7: [(1, 'A1u'), (2, 'A2u'), (1, 'B1u'), (1, 'B2u'), (3, 'E1u'), (2, 'E2u')],
#    8: [(2, 'A1g'), (1, 'A2g'), (1, 'B1g'), (1, 'B2g'), (3, 'E1g'), (3, 'E2g')],
#    9: [(1, 'A1u'), (2, 'A2u'), (2, 'B1u'), (2, 'B2u'), (3, 'E1u'), (3, 'E2u')],
#    10: [(2, 'A1g'),
#     (1, 'A2g'),
#     (2, 'B1g'),
#     (2, 'B2g'),
#     (3, 'E1g'),
#     (4, 'E2g')],
#    11: [(1, 'A1u'),
#     (2, 'A2u'),
#     (2, 'B1u'),
#     (2, 'B2u'),
#     (4, 'E1u'),
#     (4, 'E2u')]},
#   'T': {0: [(1, 'A')],
#    1: [(1, 'T')],
#    2: [(1, 'E'), (1, 'T')],
#    3: [(1, 'A'), (2, 'T')],
#    4: [(1, 'A'), (1, 'E'), (2, 'T')],
#    5: [(1, 'E'), (3, 'T')],
#    6: [(2, 'A'), (1, 'E'), (3, 'T')],
#    7: [(1, 'A'), (1, 'E'), (4, 'T')],
#    8: [(1, 'A'), (2, 'E'), (4, 'T')],
#    9: [(2, 'A'), (1, 'E'), (5, 'T')],
#    10: [(2, 'A'), (2, 'E'), (5, 'T')],
#    11: [(1, 'A'), (2, 'E'), (6, 'T')]},
#   'Th': {0: [(1, 'Ag')],
#    1: [(1, 'Tu')],
#    2: [(1, 'Eg'), (1, 'Tg')],
#    3: [(1, 'Au'), (2, 'Tu')],
#    4: [(1, 'Ag'), (1, 'Eg'), (2, 'Tg')],
#    5: [(1, 'Eu'), (3, 'Tu')],
#    6: [(2, 'Ag'), (1, 'Eg'), (3, 'Tg')],
#    7: [(1, 'Au'), (1, 'Eu'), (4, 'Tu')],
#    8: [(1, 'Ag'), (2, 'Eg'), (4, 'Tg')],
#    9: [(2, 'Au'), (1, 'Eu'), (5, 'Tu')],
#    10: [(2, 'Ag'), (2, 'Eg'), (5, 'Tg')],
#    11: [(1, 'Au'), (2, 'Eu'), (6, 'Tu')]},
#   'O': {0: [(1, 'A1')],
#    1: [(1, 'T1')],
#    2: [(1, 'E'), (1, 'T2')],
#    3: [(1, 'A2'), (1, 'T1'), (1, 'T2')],
#    4: [(1, 'A1'), (1, 'E'), (1, 'T1'), (1, 'T2')],
#    5: [(1, 'E'), (2, 'T1'), (1, 'T2')],
#    6: [(1, 'A1'), (1, 'A2'), (1, 'E'), (1, 'T1'), (2, 'T2')],
#    7: [(1, 'A2'), (1, 'E'), (2, 'T1'), (2, 'T2')],
#    8: [(1, 'A1'), (2, 'E'), (2, 'T1'), (2, 'T2')],
#    9: [(1, 'A1'), (1, 'A2'), (1, 'E'), (3, 'T1'), (2, 'T2')],
#    10: [(1, 'A1'), (1, 'A2'), (2, 'E'), (2, 'T1'), (3, 'T2')],
#    11: [(1, 'A2'), (2, 'E'), (3, 'T1'), (3, 'T2')]},
#   'Td': {0: [(1, 'A1')],
#    1: [(1, 'T2')],
#    2: [(1, 'E'), (1, 'T2')],
#    3: [(1, 'A1'), (1, 'T1'), (1, 'T2')],
#    4: [(1, 'A1'), (1, 'E'), (1, 'T1'), (1, 'T2')],
#    5: [(1, 'E'), (1, 'T1'), (2, 'T2')],
#    6: [(1, 'A1'), (1, 'A2'), (1, 'E'), (1, 'T1'), (2, 'T2')],
#    7: [(1, 'A1'), (1, 'E'), (2, 'T1'), (2, 'T2')],
#    8: [(1, 'A1'), (2, 'E'), (2, 'T1'), (2, 'T2')],
#    9: [(1, 'A1'), (1, 'A2'), (1, 'E'), (2, 'T1'), (3, 'T2')],
#    10: [(1, 'A1'), (1, 'A2'), (2, 'E'), (2, 'T1'), (3, 'T2')],
#    11: [(1, 'A1'), (2, 'E'), (3, 'T1'), (3, 'T2')]},
#   'Oh': {0: [(1, 'A1g')],
#    1: [(1, 'T1u')],
#    2: [(1, 'Eg'), (1, 'T2g')],
#    3: [(1, 'A2u'), (1, 'T1u'), (1, 'T2u')],
#    4: [(1, 'A1g'), (1, 'Eg'), (1, 'T1g'), (1, 'T2g')],
#    5: [(1, 'Eu'), (2, 'T1u'), (1, 'T2u')],
#    6: [(1, 'A1g'), (1, 'A2g'), (1, 'Eg'), (1, 'T1g'), (2, 'T2g')],
#    7: [(1, 'A2u'), (1, 'Eu'), (2, 'T1u'), (2, 'T2u')],
#    8: [(1, 'A1g'), (2, 'Eg'), (2, 'T1g'), (2, 'T2g')],
#    9: [(1, 'A1u'), (1, 'A2u'), (1, 'Eu'), (3, 'T1u'), (2, 'T2u')],
#    10: [(1, 'A1g'), (1, 'A2g'), (2, 'Eg'), (2, 'T1g'), (3, 'T2g')],
#    11: [(1, 'A2u'), (2, 'Eu'), (3, 'T1u'), (3, 'T2u')]},
#   'C4-c': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'Ea'), (1, 'Eb')],
#    2: [(1, 'A'), (2, 'B'), (1, 'Ea'), (1, 'Eb')],
#    3: [(1, 'A'), (2, 'B'), (2, 'Ea'), (2, 'Eb')],
#    4: [(3, 'A'), (2, 'B'), (2, 'Ea'), (2, 'Eb')],
#    5: [(3, 'A'), (2, 'B'), (3, 'Ea'), (3, 'Eb')],
#    6: [(3, 'A'), (4, 'B'), (3, 'Ea'), (3, 'Eb')],
#    7: [(3, 'A'), (4, 'B'), (4, 'Ea'), (4, 'Eb')],
#    8: [(5, 'A'), (4, 'B'), (4, 'Ea'), (4, 'Eb')],
#    9: [(5, 'A'), (4, 'B'), (5, 'Ea'), (5, 'Eb')],
#    10: [(5, 'A'), (6, 'B'), (5, 'Ea'), (5, 'Eb')],
#    11: [(5, 'A'), (6, 'B'), (6, 'Ea'), (6, 'Eb')]},
#   'S4-c': {0: [(1, 'A')],
#    1: [(1, 'B'), (1, 'Ea'), (1, 'Eb')],
#    2: [(1, 'A'), (2, 'B'), (1, 'Ea'), (1, 'Eb')],
#    3: [(2, 'A'), (1, 'B'), (2, 'Ea'), (2, 'Eb')],
#    4: [(3, 'A'), (2, 'B'), (2, 'Ea'), (2, 'Eb')],
#    5: [(2, 'A'), (3, 'B'), (3, 'Ea'), (3, 'Eb')],
#    6: [(3, 'A'), (4, 'B'), (3, 'Ea'), (3, 'Eb')],
#    7: [(4, 'A'), (3, 'B'), (4, 'Ea'), (4, 'Eb')],
#    8: [(5, 'A'), (4, 'B'), (4, 'Ea'), (4, 'Eb')],
#    9: [(4, 'A'), (5, 'B'), (5, 'Ea'), (5, 'Eb')],
#    10: [(5, 'A'), (6, 'B'), (5, 'Ea'), (5, 'Eb')],
#    11: [(6, 'A'), (5, 'B'), (6, 'Ea'), (6, 'Eb')]},
#   'C4h-c': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'Eua'), (1, 'Eub')],
#    2: [(1, 'Ag'), (2, 'Bg'), (1, 'Ega'), (1, 'Egb')],
#    3: [(1, 'Au'), (2, 'Bu'), (2, 'Eua'), (2, 'Eub')],
#    4: [(3, 'Ag'), (2, 'Bg'), (2, 'Ega'), (2, 'Egb')],
#    5: [(3, 'Au'), (2, 'Bu'), (3, 'Eua'), (3, 'Eub')],
#    6: [(3, 'Ag'), (4, 'Bg'), (3, 'Ega'), (3, 'Egb')],
#    7: [(3, 'Au'), (4, 'Bu'), (4, 'Eua'), (4, 'Eub')],
#    8: [(5, 'Ag'), (4, 'Bg'), (4, 'Ega'), (4, 'Egb')],
#    9: [(5, 'Au'), (4, 'Bu'), (5, 'Eua'), (5, 'Eub')],
#    10: [(5, 'Ag'), (6, 'Bg'), (5, 'Ega'), (5, 'Egb')],
#    11: [(5, 'Au'), (6, 'Bu'), (6, 'Eua'), (6, 'Eub')]},
#   'C3-c': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'Ea'), (1, 'Eb')],
#    2: [(1, 'A'), (2, 'Ea'), (2, 'Eb')],
#    3: [(3, 'A'), (2, 'Ea'), (2, 'Eb')],
#    4: [(3, 'A'), (3, 'Ea'), (3, 'Eb')],
#    5: [(3, 'A'), (4, 'Ea'), (4, 'Eb')],
#    6: [(5, 'A'), (4, 'Ea'), (4, 'Eb')],
#    7: [(5, 'A'), (5, 'Ea'), (5, 'Eb')],
#    8: [(5, 'A'), (6, 'Ea'), (6, 'Eb')],
#    9: [(7, 'A'), (6, 'Ea'), (6, 'Eb')],
#    10: [(7, 'A'), (7, 'Ea'), (7, 'Eb')],
#    11: [(7, 'A'), (8, 'Ea'), (8, 'Eb')]},
#   'C3i-c': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'Eua'), (1, 'Eub')],
#    2: [(1, 'Ag'), (2, 'Ega'), (2, 'Egb')],
#    3: [(3, 'Au'), (2, 'Eua'), (2, 'Eub')],
#    4: [(3, 'Ag'), (3, 'Ega'), (3, 'Egb')],
#    5: [(3, 'Au'), (4, 'Eua'), (4, 'Eub')],
#    6: [(5, 'Ag'), (4, 'Ega'), (4, 'Egb')],
#    7: [(5, 'Au'), (5, 'Eua'), (5, 'Eub')],
#    8: [(5, 'Ag'), (6, 'Ega'), (6, 'Egb')],
#    9: [(7, 'Au'), (6, 'Eua'), (6, 'Eub')],
#    10: [(7, 'Ag'), (7, 'Ega'), (7, 'Egb')],
#    11: [(7, 'Au'), (8, 'Eua'), (8, 'Eub')]},
#   'C6-c': {0: [(1, 'A')],
#    1: [(1, 'A'), (1, 'E1a'), (1, 'E1b')],
#    2: [(1, 'A'), (1, 'E1a'), (1, 'E1b'), (1, 'E2a'), (1, 'E2b')],
#    3: [(1, 'A'), (2, 'B'), (1, 'E1a'), (1, 'E1b'), (1, 'E2a'), (1, 'E2b')],
#    4: [(1, 'A'), (2, 'B'), (1, 'E1a'), (1, 'E1b'), (2, 'E2a'), (2, 'E2b')],
#    5: [(1, 'A'), (2, 'B'), (2, 'E1a'), (2, 'E1b'), (2, 'E2a'), (2, 'E2b')],
#    6: [(3, 'A'), (2, 'B'), (2, 'E1a'), (2, 'E1b'), (2, 'E2a'), (2, 'E2b')],
#    7: [(3, 'A'), (2, 'B'), (3, 'E1a'), (3, 'E1b'), (2, 'E2a'), (2, 'E2b')],
#    8: [(3, 'A'), (2, 'B'), (3, 'E1a'), (3, 'E1b'), (3, 'E2a'), (3, 'E2b')],
#    9: [(3, 'A'), (4, 'B'), (3, 'E1a'), (3, 'E1b'), (3, 'E2a'), (3, 'E2b')],
#    10: [(3, 'A'), (4, 'B'), (3, 'E1a'), (3, 'E1b'), (4, 'E2a'), (4, 'E2b')],
#    11: [(3, 'A'), (4, 'B'), (4, 'E1a'), (4, 'E1b'), (4, 'E2a'), (4, 'E2b')]},
#   'C3h-c': {0: [(1, "A'")],
#    1: [(1, "A''"), (1, "Ea'"), (1, "Eb'")],
#    2: [(1, "A'"), (1, "Ea'"), (1, "Ea''"), (1, "Eb'"), (1, "Eb''")],
#    3: [(2, "A'"),
#     (1, "A''"),
#     (1, "Ea'"),
#     (1, "Ea''"),
#     (1, "Eb'"),
#     (1, "Eb''")],
#    4: [(1, "A'"),
#     (2, "A''"),
#     (2, "Ea'"),
#     (1, "Ea''"),
#     (2, "Eb'"),
#     (1, "Eb''")],
#    5: [(2, "A'"),
#     (1, "A''"),
#     (2, "Ea'"),
#     (2, "Ea''"),
#     (2, "Eb'"),
#     (2, "Eb''")],
#    6: [(3, "A'"),
#     (2, "A''"),
#     (2, "Ea'"),
#     (2, "Ea''"),
#     (2, "Eb'"),
#     (2, "Eb''")],
#    7: [(2, "A'"),
#     (3, "A''"),
#     (3, "Ea'"),
#     (2, "Ea''"),
#     (3, "Eb'"),
#     (2, "Eb''")],
#    8: [(3, "A'"),
#     (2, "A''"),
#     (3, "Ea'"),
#     (3, "Ea''"),
#     (3, "Eb'"),
#     (3, "Eb''")],
#    9: [(4, "A'"),
#     (3, "A''"),
#     (3, "Ea'"),
#     (3, "Ea''"),
#     (3, "Eb'"),
#     (3, "Eb''")],
#    10: [(3, "A'"),
#     (4, "A''"),
#     (4, "Ea'"),
#     (3, "Ea''"),
#     (4, "Eb'"),
#     (3, "Eb''")],
#    11: [(4, "A'"),
#     (3, "A''"),
#     (4, "Ea'"),
#     (4, "Ea''"),
#     (4, "Eb'"),
#     (4, "Eb''")]},
#   'C6h-c': {0: [(1, 'Ag')],
#    1: [(1, 'Au'), (1, 'E1ua'), (1, 'E1ub')],
#    2: [(1, 'Ag'), (1, 'E1ga'), (1, 'E1gb'), (1, 'E2ga'), (1, 'E2gb')],
#    3: [(1, 'Au'),
#     (2, 'Bu'),
#     (1, 'E1ua'),
#     (1, 'E1ub'),
#     (1, 'E2ua'),
#     (1, 'E2ub')],
#    4: [(1, 'Ag'),
#     (2, 'Bg'),
#     (1, 'E1ga'),
#     (1, 'E1gb'),
#     (2, 'E2ga'),
#     (2, 'E2gb')],
#    5: [(1, 'Au'),
#     (2, 'Bu'),
#     (2, 'E1ua'),
#     (2, 'E1ub'),
#     (2, 'E2ua'),
#     (2, 'E2ub')],
#    6: [(3, 'Ag'),
#     (2, 'Bg'),
#     (2, 'E1ga'),
#     (2, 'E1gb'),
#     (2, 'E2ga'),
#     (2, 'E2gb')],
#    7: [(3, 'Au'),
#     (2, 'Bu'),
#     (3, 'E1ua'),
#     (3, 'E1ub'),
#     (2, 'E2ua'),
#     (2, 'E2ub')],
#    8: [(3, 'Ag'),
#     (2, 'Bg'),
#     (3, 'E1ga'),
#     (3, 'E1gb'),
#     (3, 'E2ga'),
#     (3, 'E2gb')],
#    9: [(3, 'Au'),
#     (4, 'Bu'),
#     (3, 'E1ua'),
#     (3, 'E1ub'),
#     (3, 'E2ua'),
#     (3, 'E2ub')],
#    10: [(3, 'Ag'),
#     (4, 'Bg'),
#     (3, 'E1ga'),
#     (3, 'E1gb'),
#     (4, 'E2ga'),
#     (4, 'E2gb')],
#    11: [(3, 'Au'),
#     (4, 'Bu'),
#     (4, 'E1ua'),
#     (4, 'E1ub'),
#     (4, 'E2ua'),
#     (4, 'E2ub')]},
#   'T-c': {0: [(1, 'A')],
#    1: [(1, 'T')],
#    2: [(1, 'Ea'), (1, 'Eb'), (1, 'T')],
#    3: [(1, 'A'), (2, 'T')],
#    4: [(1, 'A'), (1, 'Ea'), (1, 'Eb'), (2, 'T')],
#    5: [(1, 'Ea'), (1, 'Eb'), (3, 'T')],
#    6: [(2, 'A'), (1, 'Ea'), (1, 'Eb'), (3, 'T')],
#    7: [(1, 'A'), (1, 'Ea'), (1, 'Eb'), (4, 'T')],
#    8: [(1, 'A'), (2, 'Ea'), (2, 'Eb'), (4, 'T')],
#    9: [(2, 'A'), (1, 'Ea'), (1, 'Eb'), (5, 'T')],
#    10: [(2, 'A'), (2, 'Ea'), (2, 'Eb'), (5, 'T')],
#    11: [(1, 'A'), (2, 'Ea'), (2, 'Eb'), (6, 'T')]},
#   'Th-c': {0: [(1, 'Ag')],
#    1: [(1, 'Tu')],
#    2: [(1, 'Ega'), (1, 'Egb'), (1, 'Tg')],
#    3: [(1, 'Au'), (2, 'Tu')],
#    4: [(1, 'Ag'), (1, 'Ega'), (1, 'Egb'), (2, 'Tg')],
#    5: [(1, 'Eua'), (1, 'Eub'), (3, 'Tu')],
#    6: [(2, 'Ag'), (1, 'Ega'), (1, 'Egb'), (3, 'Tg')],
#    7: [(1, 'Au'), (1, 'Eua'), (1, 'Eub'), (4, 'Tu')],
#    8: [(1, 'Ag'), (2, 'Ega'), (2, 'Egb'), (4, 'Tg')],
#    9: [(2, 'Au'), (1, 'Eua'), (1, 'Eub'), (5, 'Tu')],
#    10: [(2, 'Ag'), (2, 'Ega'), (2, 'Egb'), (5, 'Tg')],
#    11: [(1, 'Au'), (2, 'Eua'), (2, 'Eub'), (6, 'Tu')]}}}

# %%
for k, (ex, u) in info["harmonics"]["basis_function"].items():
    print("===",k,"===")
    display(ex, sp.Matrix(u).T)
# Out:
# === s ===
# 1
# Matrix([[1]])
# === px ===
# x
# Matrix([[-sqrt(2)/2, 0, sqrt(2)/2]])
# === py ===
# y
# Matrix([[sqrt(2)*I/2, 0, sqrt(2)*I/2]])
# === pz ===
# z
# Matrix([[0, 1, 0]])
# === du ===
# -x**2/2 - y**2/2 + z**2
# Matrix([[0, 0, 1, 0, 0]])
# === dv ===
# sqrt(3)*(x**2 - y**2)/2
# Matrix([[sqrt(2)/2, 0, 0, 0, sqrt(2)/2]])
# === dyz ===
# sqrt(3)*y*z
# Matrix([[0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0]])
# === dxz ===
# sqrt(3)*x*z
# Matrix([[0, -sqrt(2)/2, 0, sqrt(2)/2, 0]])
# === dxy ===
# sqrt(3)*x*y
# Matrix([[-sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2]])
# === f3 ===
# sqrt(15)*x*y*z
# Matrix([[0, -sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2, 0]])
# === fax ===
# x*(2*x**2 - 3*y**2 - 3*z**2)/2
# Matrix([[-sqrt(5)/4, 0, sqrt(3)/4, 0, -sqrt(3)/4, 0, sqrt(5)/4]])
# === fay ===
# y*(-3*x**2 + 2*y**2 - 3*z**2)/2
# Matrix([[-sqrt(5)*I/4, 0, -sqrt(3)*I/4, 0, -sqrt(3)*I/4, 0, -sqrt(5)*I/4]])
# === faz ===
# z*(-3*x**2 - 3*y**2 + 2*z**2)/2
# Matrix([[0, 0, 0, 1, 0, 0, 0]])
# === fbx ===
# sqrt(15)*x*(y**2 - z**2)/2
# Matrix([[sqrt(3)/4, 0, sqrt(5)/4, 0, -sqrt(5)/4, 0, -sqrt(3)/4]])
# === fby ===
# sqrt(15)*y*(-x**2 + z**2)/2
# Matrix([[-sqrt(3)*I/4, 0, sqrt(5)*I/4, 0, sqrt(5)*I/4, 0, -sqrt(3)*I/4]])
# === fbz ===
# sqrt(15)*z*(x**2 - y**2)/2
# Matrix([[0, sqrt(2)/2, 0, 0, 0, sqrt(2)/2, 0]])
# === f1 ===
# sqrt(10)*y*(3*x**2 - y**2)/4
# Matrix([[sqrt(2)*I/2, 0, 0, 0, 0, 0, sqrt(2)*I/2]])
# === f2 ===
# sqrt(10)*x*(x**2 - 3*y**2)/4
# Matrix([[-sqrt(2)/2, 0, 0, 0, 0, 0, sqrt(2)/2]])
# === f3x ===
# sqrt(6)*x*(-x**2 - y**2 + 4*z**2)/4
# Matrix([[0, 0, -sqrt(2)/2, 0, sqrt(2)/2, 0, 0]])
# === f3y ===
# sqrt(6)*y*(-x**2 - y**2 + 4*z**2)/4
# Matrix([[0, 0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0, 0]])
# === g ===
# sqrt(21)*(x**4 - 3*x**2*y**2 - 3*x**2*z**2 + y**4 - 3*y**2*z**2 + z**4)/6
# Matrix([[sqrt(30)/12, 0, 0, 0, sqrt(21)/6, 0, 0, 0, sqrt(30)/12]])
# === gu ===
# -sqrt(15)*(x**4 - 12*x**2*y**2 + 6*x**2*z**2 + y**4 + 6*y**2*z**2 - 2*z**4)/12
# Matrix([[-sqrt(42)/12, 0, 0, 0, sqrt(15)/6, 0, 0, 0, -sqrt(42)/12]])
# === gv ===
# sqrt(5)*(x - y)*(x + y)*(-x**2 - y**2 + 6*z**2)/4
# Matrix([[0, 0, sqrt(2)/2, 0, 0, 0, sqrt(2)/2, 0, 0]])
# === gax ===
# sqrt(35)*y*z*(y - z)*(y + z)/2
# Matrix([[0, -I/4, 0, -sqrt(7)*I/4, 0, -sqrt(7)*I/4, 0, -I/4, 0]])
# === gay ===
# sqrt(35)*x*z*(-x + z)*(x + z)/2
# Matrix([[0, 1/4, 0, -sqrt(7)/4, 0, sqrt(7)/4, 0, -1/4, 0]])
# === gaz ===
# sqrt(35)*x*y*(x - y)*(x + y)/2
# Matrix([[-sqrt(2)*I/2, 0, 0, 0, 0, 0, 0, 0, sqrt(2)*I/2]])
# === gbx ===
# sqrt(5)*y*z*(6*x**2 - y**2 - z**2)/2
# Matrix([[0, sqrt(7)*I/4, 0, -I/4, 0, -I/4, 0, sqrt(7)*I/4, 0]])
# === gby ===
# sqrt(5)*x*z*(-x**2 + 6*y**2 - z**2)/2
# Matrix([[0, sqrt(7)/4, 0, 1/4, 0, -1/4, 0, -sqrt(7)/4, 0]])
# === gbz ===
# sqrt(5)*x*y*(-x**2 - y**2 + 6*z**2)/2
# Matrix([[0, 0, -sqrt(2)*I/2, 0, 0, 0, sqrt(2)*I/2, 0, 0]])
# === g0 ===
# 3*x**4/8 + 3*x**2*y**2/4 - 3*x**2*z**2 + 3*y**4/8 - 3*y**2*z**2 + z**4
# Matrix([[0, 0, 0, 0, 1, 0, 0, 0, 0]])
# === ga ===
# sqrt(70)*x*z*(x**2 - 3*y**2)/4
# Matrix([[0, -sqrt(2)/2, 0, 0, 0, 0, 0, sqrt(2)/2, 0]])
# === gb ===
# sqrt(70)*y*z*(3*x**2 - y**2)/4
# Matrix([[0, sqrt(2)*I/2, 0, 0, 0, 0, 0, sqrt(2)*I/2, 0]])
# === gc ===
# sqrt(35)*(x**2 - 2*x*y - y**2)*(x**2 + 2*x*y - y**2)/8
# Matrix([[sqrt(2)/2, 0, 0, 0, 0, 0, 0, 0, sqrt(2)/2]])
# === gau ===
# -sqrt(10)*y*z*(3*x**2 + 3*y**2 - 4*z**2)/4
# Matrix([[0, 0, 0, sqrt(2)*I/2, 0, sqrt(2)*I/2, 0, 0, 0]])
# === gav ===
# sqrt(10)*x*z*(3*x**2 + 3*y**2 - 4*z**2)/4
# Matrix([[0, 0, 0, sqrt(2)/2, 0, -sqrt(2)/2, 0, 0, 0]])

# %%
info["id"]
# Out:
# {'C1': 'PG:1',
#  'Ci': 'PG:2',
#  'C2': 'PG:3',
#  'Cs': 'PG:4',
#  'C2h': 'PG:5',
#  'D2': 'PG:6',
#  'C2v': 'PG:7',
#  'D2h': 'PG:8',
#  'C4': 'PG:9',
#  'S4': 'PG:10',
#  'C4h': 'PG:11',
#  'D4': 'PG:12',
#  'C4v': 'PG:13',
#  'D2d': 'PG:14',
#  'D4h': 'PG:15',
#  'C3': 'PG:16',
#  'C3i': 'PG:17',
#  'D3': 'PG:18',
#  'C3v': 'PG:19',
#  'D3d': 'PG:20',
#  'C6': 'PG:21',
#  'C3h': 'PG:22',
#  'C6h': 'PG:23',
#  'D6': 'PG:24',
#  'C6v': 'PG:25',
#  'D3h': 'PG:26',
#  'D6h': 'PG:27',
#  'T': 'PG:28',
#  'Th': 'PG:29',
#  'O': 'PG:30',
#  'Td': 'PG:31',
#  'Oh': 'PG:32',
#  'D2d-1': 'PG:33',
#  'D3-1': 'PG:34',
#  'C3v-1': 'PG:35',
#  'D3d-1': 'PG:36',
#  'D3h-1': 'PG:37',
#  'C4-c': 'PG:38',
#  'S4-c': 'PG:39',
#  'C4h-c': 'PG:40',
#  'C3-c': 'PG:41',
#  'C3i-c': 'PG:42',
#  'C6-c': 'PG:43',
#  'C3h-c': 'PG:44',
#  'C6h-c': 'PG:45',
#  'T-c': 'PG:46',
#  'Th-c': 'PG:47',
#  'C1^1': 'SG:1',
#  'Ci^1': 'SG:2',
#  'C2^1': 'SG:3',
#  'C2^2': 'SG:4',
#  'C2^3': 'SG:5',
#  'Cs^1': 'SG:6',
#  'Cs^2': 'SG:7',
#  'Cs^3': 'SG:8',
#  'Cs^4': 'SG:9',
#  'C2h^1': 'SG:10',
#  'C2h^2': 'SG:11',
#  'C2h^3': 'SG:12',
#  'C2h^4': 'SG:13',
#  'C2h^5': 'SG:14',
#  'C2h^6': 'SG:15',
#  'D2^1': 'SG:16',
#  'D2^2': 'SG:17',
#  'D2^3': 'SG:18',
#  'D2^4': 'SG:19',
#  'D2^5': 'SG:20',
#  'D2^6': 'SG:21',
#  'D2^7': 'SG:22',
#  'D2^8': 'SG:23',
#  'D2^9': 'SG:24',
#  'C2v^1': 'SG:25',
#  'C2v^2': 'SG:26',
#  'C2v^3': 'SG:27',
#  'C2v^4': 'SG:28',
#  'C2v^5': 'SG:29',
#  'C2v^6': 'SG:30',
#  'C2v^7': 'SG:31',
#  'C2v^8': 'SG:32',
#  'C2v^9': 'SG:33',
#  'C2v^10': 'SG:34',
#  'C2v^11': 'SG:35',
#  'C2v^12': 'SG:36',
#  'C2v^13': 'SG:37',
#  'C2v^14': 'SG:38',
#  'C2v^15': 'SG:39',
#  'C2v^16': 'SG:40',
#  'C2v^17': 'SG:41',
#  'C2v^18': 'SG:42',
#  'C2v^19': 'SG:43',
#  'C2v^20': 'SG:44',
#  'C2v^21': 'SG:45',
#  'C2v^22': 'SG:46',
#  'D2h^1': 'SG:47',
#  'D2h^2': 'SG:48',
#  'D2h^3': 'SG:49',
#  'D2h^4': 'SG:50',
#  'D2h^5': 'SG:51',
#  'D2h^6': 'SG:52',
#  'D2h^7': 'SG:53',
#  'D2h^8': 'SG:54',
#  'D2h^9': 'SG:55',
#  'D2h^10': 'SG:56',
#  'D2h^11': 'SG:57',
#  'D2h^12': 'SG:58',
#  'D2h^13': 'SG:59',
#  'D2h^14': 'SG:60',
#  'D2h^15': 'SG:61',
#  'D2h^16': 'SG:62',
#  'D2h^17': 'SG:63',
#  'D2h^18': 'SG:64',
#  'D2h^19': 'SG:65',
#  'D2h^20': 'SG:66',
#  'D2h^21': 'SG:67',
#  'D2h^22': 'SG:68',
#  'D2h^23': 'SG:69',
#  'D2h^24': 'SG:70',
#  'D2h^25': 'SG:71',
#  'D2h^26': 'SG:72',
#  'D2h^27': 'SG:73',
#  'D2h^28': 'SG:74',
#  'C4^1': 'SG:75',
#  'C4^2': 'SG:76',
#  'C4^3': 'SG:77',
#  'C4^4': 'SG:78',
#  'C4^5': 'SG:79',
#  'C4^6': 'SG:80',
#  'S4^1': 'SG:81',
#  'S4^2': 'SG:82',
#  'C4h^1': 'SG:83',
#  'C4h^2': 'SG:84',
#  'C4h^3': 'SG:85',
#  'C4h^4': 'SG:86',
#  'C4h^5': 'SG:87',
#  'C4h^6': 'SG:88',
#  'D4^1': 'SG:89',
#  'D4^2': 'SG:90',
#  'D4^3': 'SG:91',
#  'D4^4': 'SG:92',
#  'D4^5': 'SG:93',
#  'D4^6': 'SG:94',
#  'D4^7': 'SG:95',
#  'D4^8': 'SG:96',
#  'D4^9': 'SG:97',
#  'D4^10': 'SG:98',
#  'C4v^1': 'SG:99',
#  'C4v^2': 'SG:100',
#  'C4v^3': 'SG:101',
#  'C4v^4': 'SG:102',
#  'C4v^5': 'SG:103',
#  'C4v^6': 'SG:104',
#  'C4v^7': 'SG:105',
#  'C4v^8': 'SG:106',
#  'C4v^9': 'SG:107',
#  'C4v^10': 'SG:108',
#  'C4v^11': 'SG:109',
#  'C4v^12': 'SG:110',
#  'D2d^1': 'SG:111',
#  'D2d^2': 'SG:112',
#  'D2d^3': 'SG:113',
#  'D2d^4': 'SG:114',
#  'D2d^5': 'SG:115',
#  'D2d^6': 'SG:116',
#  'D2d^7': 'SG:117',
#  'D2d^8': 'SG:118',
#  'D2d^9': 'SG:119',
#  'D2d^10': 'SG:120',
#  'D2d^11': 'SG:121',
#  'D2d^12': 'SG:122',
#  'D4h^1': 'SG:123',
#  'D4h^2': 'SG:124',
#  'D4h^3': 'SG:125',
#  'D4h^4': 'SG:126',
#  'D4h^5': 'SG:127',
#  'D4h^6': 'SG:128',
#  'D4h^7': 'SG:129',
#  'D4h^8': 'SG:130',
#  'D4h^9': 'SG:131',
#  'D4h^10': 'SG:132',
#  'D4h^11': 'SG:133',
#  'D4h^12': 'SG:134',
#  'D4h^13': 'SG:135',
#  'D4h^14': 'SG:136',
#  'D4h^15': 'SG:137',
#  'D4h^16': 'SG:138',
#  'D4h^17': 'SG:139',
#  'D4h^18': 'SG:140',
#  'D4h^19': 'SG:141',
#  'D4h^20': 'SG:142',
#  'C3^1': 'SG:143',
#  'C3^2': 'SG:144',
#  'C3^3': 'SG:145',
#  'C3^4': 'SG:146',
#  'C3i^1': 'SG:147',
#  'C3i^2': 'SG:148',
#  'D3^1': 'SG:149',
#  'D3^2': 'SG:150',
#  'D3^3': 'SG:151',
#  'D3^4': 'SG:152',
#  'D3^5': 'SG:153',
#  'D3^6': 'SG:154',
#  'D3^7': 'SG:155',
#  'C3v^1': 'SG:156',
#  'C3v^2': 'SG:157',
#  'C3v^3': 'SG:158',
#  'C3v^4': 'SG:159',
#  'C3v^5': 'SG:160',
#  'C3v^6': 'SG:161',
#  'D3d^1': 'SG:162',
#  'D3d^2': 'SG:163',
#  'D3d^3': 'SG:164',
#  'D3d^4': 'SG:165',
#  'D3d^5': 'SG:166',
#  'D3d^6': 'SG:167',
#  'C6^1': 'SG:168',
#  'C6^2': 'SG:169',
#  'C6^3': 'SG:170',
#  'C6^4': 'SG:171',
#  'C6^5': 'SG:172',
#  'C6^6': 'SG:173',
#  'C3h^1': 'SG:174',
#  'C6h^1': 'SG:175',
#  'C6h^2': 'SG:176',
#  'D6^1': 'SG:177',
#  'D6^2': 'SG:178',
#  'D6^3': 'SG:179',
#  'D6^4': 'SG:180',
#  'D6^5': 'SG:181',
#  'D6^6': 'SG:182',
#  'C6v^1': 'SG:183',
#  'C6v^2': 'SG:184',
#  'C6v^3': 'SG:185',
#  'C6v^4': 'SG:186',
#  'D3h^1': 'SG:187',
#  'D3h^2': 'SG:188',
#  'D3h^3': 'SG:189',
#  'D3h^4': 'SG:190',
#  'D6h^1': 'SG:191',
#  'D6h^2': 'SG:192',
#  'D6h^3': 'SG:193',
#  'D6h^4': 'SG:194',
#  'T^1': 'SG:195',
#  'T^2': 'SG:196',
#  'T^3': 'SG:197',
#  'T^4': 'SG:198',
#  'T^5': 'SG:199',
#  'Th^1': 'SG:200',
#  'Th^2': 'SG:201',
#  'Th^3': 'SG:202',
#  'Th^4': 'SG:203',
#  'Th^5': 'SG:204',
#  'Th^6': 'SG:205',
#  'Th^7': 'SG:206',
#  'O^1': 'SG:207',
#  'O^2': 'SG:208',
#  'O^3': 'SG:209',
#  'O^4': 'SG:210',
#  'O^5': 'SG:211',
#  'O^6': 'SG:212',
#  'O^7': 'SG:213',
#  'O^8': 'SG:214',
#  'Td^1': 'SG:215',
#  'Td^2': 'SG:216',
#  'Td^3': 'SG:217',
#  'Td^4': 'SG:218',
#  'Td^5': 'SG:219',
#  'Td^6': 'SG:220',
#  'Oh^1': 'SG:221',
#  'Oh^2': 'SG:222',
#  'Oh^3': 'SG:223',
#  'Oh^4': 'SG:224',
#  'Oh^5': 'SG:225',
#  'Oh^6': 'SG:226',
#  'Oh^7': 'SG:227',
#  'Oh^8': 'SG:228',
#  'Oh^9': 'SG:229',
#  'Oh^10': 'SG:230',
#  '1.1.1': 'MPG:1.1.1',
#  '1.2.2': 'MPG:1.2.2',
#  '2.1.3': 'MPG:2.1.3',
#  '2.2.4': 'MPG:2.2.4',
#  '2.3.5': 'MPG:2.3.5',
#  '3.1.6': 'MPG:3.1.6',
#  '3.2.7': 'MPG:3.2.7',
#  '3.3.8': 'MPG:3.3.8',
#  '4.1.9': 'MPG:4.1.9',
#  '4.2.10': 'MPG:4.2.10',
#  '4.3.11': 'MPG:4.3.11',
#  '5.1.12': 'MPG:5.1.12',
#  '5.2.13': 'MPG:5.2.13',
#  '5.3.14': 'MPG:5.3.14',
#  '5.4.15': 'MPG:5.4.15',
#  '5.5.16': 'MPG:5.5.16',
#  '6.1.17': 'MPG:6.1.17',
#  '6.2.18': 'MPG:6.2.18',
#  '6.3.19': 'MPG:6.3.19',
#  '6.4.123': 'MPG:6.4.123',
#  '7.1.20': 'MPG:7.1.20',
#  '7.2.21': 'MPG:7.2.21',
#  '7.3.22': 'MPG:7.3.22',
#  '7.4.23': 'MPG:7.4.23',
#  '7.5.124': 'MPG:7.5.124',
#  '8.1.24': 'MPG:8.1.24',
#  '8.2.25': 'MPG:8.2.25',
#  '8.3.26': 'MPG:8.3.26',
#  '8.4.27': 'MPG:8.4.27',
#  '8.5.28': 'MPG:8.5.28',
#  '8.6.125': 'MPG:8.6.125',
#  '8.7.126': 'MPG:8.7.126',
#  '8.8.127': 'MPG:8.8.127',
#  '8.9.128': 'MPG:8.9.128',
#  '9.1.29': 'MPG:9.1.29',
#  '9.2.30': 'MPG:9.2.30',
#  '9.3.31': 'MPG:9.3.31',
#  '10.1.32': 'MPG:10.1.32',
#  '10.2.33': 'MPG:10.2.33',
#  '10.3.34': 'MPG:10.3.34',
#  '11.1.35': 'MPG:11.1.35',
#  '11.2.36': 'MPG:11.2.36',
#  '11.3.37': 'MPG:11.3.37',
#  '11.4.38': 'MPG:11.4.38',
#  '11.5.39': 'MPG:11.5.39',
#  '12.1.40': 'MPG:12.1.40',
#  '12.2.41': 'MPG:12.2.41',
#  '12.3.42': 'MPG:12.3.42',
#  '12.4.43': 'MPG:12.4.43',
#  '12.5.129': 'MPG:12.5.129',
#  '13.1.44': 'MPG:13.1.44',
#  '13.2.45': 'MPG:13.2.45',
#  '13.3.46': 'MPG:13.3.46',
#  '13.4.47': 'MPG:13.4.47',
#  '13.5.130': 'MPG:13.5.130',
#  '14.1.48': 'MPG:14.1.48',
#  '14.2.49': 'MPG:14.2.49',
#  '14.3.50': 'MPG:14.3.50',
#  '14.4.51': 'MPG:14.4.51',
#  '14.5.52': 'MPG:14.5.52',
#  '15.1.53': 'MPG:15.1.53',
#  '15.2.54': 'MPG:15.2.54',
#  '15.3.55': 'MPG:15.3.55',
#  '15.4.56': 'MPG:15.4.56',
#  '15.5.57': 'MPG:15.5.57',
#  '15.6.58': 'MPG:15.6.58',
#  '15.7.59': 'MPG:15.7.59',
#  '15.8.136': 'MPG:15.8.136',
#  '15.9.137': 'MPG:15.9.137',
#  '16.1.60': 'MPG:16.1.60',
#  '16.2.61': 'MPG:16.2.61',
#  '17.1.62': 'MPG:17.1.62',
#  '17.2.63': 'MPG:17.2.63',
#  '17.3.64': 'MPG:17.3.64',
#  '18.1.65': 'MPG:18.1.65',
#  '18.2.66': 'MPG:18.2.66',
#  '18.3.67': 'MPG:18.3.67',
#  '19.1.68': 'MPG:19.1.68',
#  '19.2.69': 'MPG:19.2.69',
#  '19.3.70': 'MPG:19.3.70',
#  '20.1.71': 'MPG:20.1.71',
#  '20.2.72': 'MPG:20.2.72',
#  '20.3.73': 'MPG:20.3.73',
#  '20.4.74': 'MPG:20.4.74',
#  '20.5.75': 'MPG:20.5.75',
#  '21.1.76': 'MPG:21.1.76',
#  '21.2.77': 'MPG:21.2.77',
#  '21.3.78': 'MPG:21.3.78',
#  '22.1.79': 'MPG:22.1.79',
#  '22.2.80': 'MPG:22.2.80',
#  '22.3.81': 'MPG:22.3.81',
#  '23.1.82': 'MPG:23.1.82',
#  '23.2.83': 'MPG:23.2.83',
#  '23.3.84': 'MPG:23.3.84',
#  '23.4.85': 'MPG:23.4.85',
#  '23.5.86': 'MPG:23.5.86',
#  '24.1.87': 'MPG:24.1.87',
#  '24.2.88': 'MPG:24.2.88',
#  '24.3.89': 'MPG:24.3.89',
#  '24.4.90': 'MPG:24.4.90',
#  '24.5.149': 'MPG:24.5.149',
#  '25.1.91': 'MPG:25.1.91',
#  '25.2.92': 'MPG:25.2.92',
#  '25.3.93': 'MPG:25.3.93',
#  '25.4.94': 'MPG:25.4.94',
#  '25.5.150': 'MPG:25.5.150',
#  '26.1.95': 'MPG:26.1.95',
#  '26.2.96': 'MPG:26.2.96',
#  '26.3.97': 'MPG:26.3.97',
#  '26.4.98': 'MPG:26.4.98',
#  '26.5.99': 'MPG:26.5.99',
#  '27.1.100': 'MPG:27.1.100',
#  '27.2.101': 'MPG:27.2.101',
#  '27.3.102': 'MPG:27.3.102',
#  '27.4.103': 'MPG:27.4.103',
#  '27.5.104': 'MPG:27.5.104',
#  '27.6.105': 'MPG:27.6.105',
#  '27.7.106': 'MPG:27.7.106',
#  '27.8.156': 'MPG:27.8.156',
#  '27.9.157': 'MPG:27.9.157',
#  '28.1.107': 'MPG:28.1.107',
#  '28.2.108': 'MPG:28.2.108',
#  '29.1.109': 'MPG:29.1.109',
#  '29.2.110': 'MPG:29.2.110',
#  '29.3.111': 'MPG:29.3.111',
#  '30.1.112': 'MPG:30.1.112',
#  '30.2.113': 'MPG:30.2.113',
#  '30.3.114': 'MPG:30.3.114',
#  '31.1.115': 'MPG:31.1.115',
#  '31.2.116': 'MPG:31.2.116',
#  '31.3.117': 'MPG:31.3.117',
#  '32.1.118': 'MPG:32.1.118',
#  '32.2.119': 'MPG:32.2.119',
#  '32.3.120': 'MPG:32.3.120',
#  '32.4.121': 'MPG:32.4.121',
#  '32.5.122': 'MPG:32.5.122',
#  '33.1.131': 'MPG:33.1.131',
#  '33.2.132': 'MPG:33.2.132',
#  '33.3.133': 'MPG:33.3.133',
#  '33.4.134': 'MPG:33.4.134',
#  '33.5.135': 'MPG:33.5.135',
#  '34.1.138': 'MPG:34.1.138',
#  '34.2.139': 'MPG:34.2.139',
#  '34.3.140': 'MPG:34.3.140',
#  '35.1.141': 'MPG:35.1.141',
#  '35.2.142': 'MPG:35.2.142',
#  '35.3.143': 'MPG:35.3.143',
#  '36.1.144': 'MPG:36.1.144',
#  '36.2.145': 'MPG:36.2.145',
#  '36.3.146': 'MPG:36.3.146',
#  '36.4.147': 'MPG:36.4.147',
#  '36.5.148': 'MPG:36.5.148',
#  '37.1.151': 'MPG:37.1.151',
#  '37.2.152': 'MPG:37.2.152',
#  '37.3.153': 'MPG:37.3.153',
#  '37.4.154': 'MPG:37.4.154',
#  '37.5.155': 'MPG:37.5.155',
#  '1.1': 'MSG:1.1',
#  '1.2': 'MSG:1.2',
#  '1.3': 'MSG:1.3',
#  '2.4': 'MSG:2.4',
#  '2.5': 'MSG:2.5',
#  '2.6': 'MSG:2.6',
#  '2.7': 'MSG:2.7',
#  '3.1': 'MSG:3.1',
#  '3.2': 'MSG:3.2',
#  '3.3': 'MSG:3.3',
#  '3.4': 'MSG:3.4',
#  '3.5': 'MSG:3.5',
#  '3.6': 'MSG:3.6',
#  '4.7': 'MSG:4.7',
#  '4.8': 'MSG:4.8',
#  '4.9': 'MSG:4.9',
#  '4.10': 'MSG:4.10',
#  '4.11': 'MSG:4.11',
#  '4.12': 'MSG:4.12',
#  '5.13': 'MSG:5.13',
#  '5.14': 'MSG:5.14',
#  '5.15': 'MSG:5.15',
#  '5.16': 'MSG:5.16',
#  '5.17': 'MSG:5.17',
#  '6.18': 'MSG:6.18',
#  '6.19': 'MSG:6.19',
#  '6.20': 'MSG:6.20',
#  '6.21': 'MSG:6.21',
#  '6.22': 'MSG:6.22',
#  '6.23': 'MSG:6.23',
#  '7.24': 'MSG:7.24',
#  '7.25': 'MSG:7.25',
#  '7.26': 'MSG:7.26',
#  '7.27': 'MSG:7.27',
#  '7.28': 'MSG:7.28',
#  '7.29': 'MSG:7.29',
#  '7.30': 'MSG:7.30',
#  '7.31': 'MSG:7.31',
#  '8.32': 'MSG:8.32',
#  '8.33': 'MSG:8.33',
#  '8.34': 'MSG:8.34',
#  '8.35': 'MSG:8.35',
#  '8.36': 'MSG:8.36',
#  '9.37': 'MSG:9.37',
#  '9.38': 'MSG:9.38',
#  '9.39': 'MSG:9.39',
#  '9.40': 'MSG:9.40',
#  '9.41': 'MSG:9.41',
#  '10.42': 'MSG:10.42',
#  '10.43': 'MSG:10.43',
#  '10.44': 'MSG:10.44',
#  '10.45': 'MSG:10.45',
#  '10.46': 'MSG:10.46',
#  '10.47': 'MSG:10.47',
#  '10.48': 'MSG:10.48',
#  '10.49': 'MSG:10.49',
#  '11.50': 'MSG:11.50',
#  '11.51': 'MSG:11.51',
#  '11.52': 'MSG:11.52',
#  '11.53': 'MSG:11.53',
#  '11.54': 'MSG:11.54',
#  '11.55': 'MSG:11.55',
#  '11.56': 'MSG:11.56',
#  '11.57': 'MSG:11.57',
#  '12.58': 'MSG:12.58',
#  '12.59': 'MSG:12.59',
#  '12.60': 'MSG:12.60',
#  '12.61': 'MSG:12.61',
#  '12.62': 'MSG:12.62',
#  '12.63': 'MSG:12.63',
#  '12.64': 'MSG:12.64',
#  '13.65': 'MSG:13.65',
#  '13.66': 'MSG:13.66',
#  '13.67': 'MSG:13.67',
#  '13.68': 'MSG:13.68',
#  '13.69': 'MSG:13.69',
#  '13.70': 'MSG:13.70',
#  '13.71': 'MSG:13.71',
#  '13.72': 'MSG:13.72',
#  '13.73': 'MSG:13.73',
#  '13.74': 'MSG:13.74',
#  '14.75': 'MSG:14.75',
#  '14.76': 'MSG:14.76',
#  '14.77': 'MSG:14.77',
#  '14.78': 'MSG:14.78',
#  '14.79': 'MSG:14.79',
#  '14.80': 'MSG:14.80',
#  '14.81': 'MSG:14.81',
#  '14.82': 'MSG:14.82',
#  '14.83': 'MSG:14.83',
#  '14.84': 'MSG:14.84',
#  '15.85': 'MSG:15.85',
#  '15.86': 'MSG:15.86',
#  '15.87': 'MSG:15.87',
#  '15.88': 'MSG:15.88',
#  '15.89': 'MSG:15.89',
#  '15.90': 'MSG:15.90',
#  '15.91': 'MSG:15.91',
#  '16.1': 'MSG:16.1',
#  '16.2': 'MSG:16.2',
#  '16.3': 'MSG:16.3',
#  '16.4': 'MSG:16.4',
#  '16.5': 'MSG:16.5',
#  '16.6': 'MSG:16.6',
#  '17.7': 'MSG:17.7',
#  '17.8': 'MSG:17.8',
#  '17.9': 'MSG:17.9',
#  '17.10': 'MSG:17.10',
#  '17.11': 'MSG:17.11',
#  '17.12': 'MSG:17.12',
#  '17.13': 'MSG:17.13',
#  '17.14': 'MSG:17.14',
#  '17.15': 'MSG:17.15',
#  '18.16': 'MSG:18.16',
#  '18.17': 'MSG:18.17',
#  '18.18': 'MSG:18.18',
#  '18.19': 'MSG:18.19',
#  '18.20': 'MSG:18.20',
#  '18.21': 'MSG:18.21',
#  '18.22': 'MSG:18.22',
#  '18.23': 'MSG:18.23',
#  '18.24': 'MSG:18.24',
#  '19.25': 'MSG:19.25',
#  '19.26': 'MSG:19.26',
#  '19.27': 'MSG:19.27',
#  '19.28': 'MSG:19.28',
#  '19.29': 'MSG:19.29',
#  '19.30': 'MSG:19.30',
#  '20.31': 'MSG:20.31',
#  '20.32': 'MSG:20.32',
#  '20.33': 'MSG:20.33',
#  '20.34': 'MSG:20.34',
#  '20.35': 'MSG:20.35',
#  '20.36': 'MSG:20.36',
#  '20.37': 'MSG:20.37',
#  '21.38': 'MSG:21.38',
#  '21.39': 'MSG:21.39',
#  '21.40': 'MSG:21.40',
#  '21.41': 'MSG:21.41',
#  '21.42': 'MSG:21.42',
#  '21.43': 'MSG:21.43',
#  '21.44': 'MSG:21.44',
#  '22.45': 'MSG:22.45',
#  '22.46': 'MSG:22.46',
#  '22.47': 'MSG:22.47',
#  '22.48': 'MSG:22.48',
#  '23.49': 'MSG:23.49',
#  '23.50': 'MSG:23.50',
#  '23.51': 'MSG:23.51',
#  '23.52': 'MSG:23.52',
#  '24.53': 'MSG:24.53',
#  '24.54': 'MSG:24.54',
#  '24.55': 'MSG:24.55',
#  '24.56': 'MSG:24.56',
#  '25.57': 'MSG:25.57',
#  '25.58': 'MSG:25.58',
#  '25.59': 'MSG:25.59',
#  '25.60': 'MSG:25.60',
#  '25.61': 'MSG:25.61',
#  '25.62': 'MSG:25.62',
#  '25.63': 'MSG:25.63',
#  '25.64': 'MSG:25.64',
#  '25.65': 'MSG:25.65',
#  '26.66': 'MSG:26.66',
#  '26.67': 'MSG:26.67',
#  '26.68': 'MSG:26.68',
#  '26.69': 'MSG:26.69',
#  '26.70': 'MSG:26.70',
#  '26.71': 'MSG:26.71',
#  '26.72': 'MSG:26.72',
#  '26.73': 'MSG:26.73',
#  '26.74': 'MSG:26.74',
#  '26.75': 'MSG:26.75',
#  '26.76': 'MSG:26.76',
#  '26.77': 'MSG:26.77',
#  '27.78': 'MSG:27.78',
#  '27.79': 'MSG:27.79',
#  '27.80': 'MSG:27.80',
#  '27.81': 'MSG:27.81',
#  '27.82': 'MSG:27.82',
#  '27.83': 'MSG:27.83',
#  '27.84': 'MSG:27.84',
#  '27.85': 'MSG:27.85',
#  '27.86': 'MSG:27.86',
#  '28.87': 'MSG:28.87',
#  '28.88': 'MSG:28.88',
#  '28.89': 'MSG:28.89',
#  '28.90': 'MSG:28.90',
#  '28.91': 'MSG:28.91',
#  '28.92': 'MSG:28.92',
#  '28.93': 'MSG:28.93',
#  '28.94': 'MSG:28.94',
#  '28.95': 'MSG:28.95',
#  '28.96': 'MSG:28.96',
#  '28.97': 'MSG:28.97',
#  '28.98': 'MSG:28.98',
#  '29.99': 'MSG:29.99',
#  '29.100': 'MSG:29.100',
#  '29.101': 'MSG:29.101',
#  '29.102': 'MSG:29.102',
#  '29.103': 'MSG:29.103',
#  '29.104': 'MSG:29.104',
#  '29.105': 'MSG:29.105',
#  '29.106': 'MSG:29.106',
#  '29.107': 'MSG:29.107',
#  '29.108': 'MSG:29.108',
#  '29.109': 'MSG:29.109',
#  '29.110': 'MSG:29.110',
#  '30.111': 'MSG:30.111',
#  '30.112': 'MSG:30.112',
#  '30.113': 'MSG:30.113',
#  '30.114': 'MSG:30.114',
#  '30.115': 'MSG:30.115',
#  '30.116': 'MSG:30.116',
#  '30.117': 'MSG:30.117',
#  '30.118': 'MSG:30.118',
#  '30.119': 'MSG:30.119',
#  '30.120': 'MSG:30.120',
#  '30.121': 'MSG:30.121',
#  '30.122': 'MSG:30.122',
#  '31.123': 'MSG:31.123',
#  '31.124': 'MSG:31.124',
#  '31.125': 'MSG:31.125',
#  '31.126': 'MSG:31.126',
#  '31.127': 'MSG:31.127',
#  '31.128': 'MSG:31.128',
#  '31.129': 'MSG:31.129',
#  '31.130': 'MSG:31.130',
#  '31.131': 'MSG:31.131',
#  '31.132': 'MSG:31.132',
#  '31.133': 'MSG:31.133',
#  '31.134': 'MSG:31.134',
#  '32.135': 'MSG:32.135',
#  '32.136': 'MSG:32.136',
#  '32.137': 'MSG:32.137',
#  '32.138': 'MSG:32.138',
#  '32.139': 'MSG:32.139',
#  '32.140': 'MSG:32.140',
#  '32.141': 'MSG:32.141',
#  '32.142': 'MSG:32.142',
#  '32.143': 'MSG:32.143',
#  '33.144': 'MSG:33.144',
#  '33.145': 'MSG:33.145',
#  '33.146': 'MSG:33.146',
#  '33.147': 'MSG:33.147',
#  '33.148': 'MSG:33.148',
#  '33.149': 'MSG:33.149',
#  '33.150': 'MSG:33.150',
#  '33.151': 'MSG:33.151',
#  '33.152': 'MSG:33.152',
#  '33.153': 'MSG:33.153',
#  '33.154': 'MSG:33.154',
#  '33.155': 'MSG:33.155',
#  '34.156': 'MSG:34.156',
#  '34.157': 'MSG:34.157',
#  '34.158': 'MSG:34.158',
#  '34.159': 'MSG:34.159',
#  '34.160': 'MSG:34.160',
#  '34.161': 'MSG:34.161',
#  '34.162': 'MSG:34.162',
#  '34.163': 'MSG:34.163',
#  '34.164': 'MSG:34.164',
#  '35.165': 'MSG:35.165',
#  '35.166': 'MSG:35.166',
#  '35.167': 'MSG:35.167',
#  '35.168': 'MSG:35.168',
#  '35.169': 'MSG:35.169',
#  '35.170': 'MSG:35.170',
#  '35.171': 'MSG:35.171',
#  '36.172': 'MSG:36.172',
#  '36.173': 'MSG:36.173',
#  '36.174': 'MSG:36.174',
#  '36.175': 'MSG:36.175',
#  '36.176': 'MSG:36.176',
#  '36.177': 'MSG:36.177',
#  '36.178': 'MSG:36.178',
#  '36.179': 'MSG:36.179',
#  '37.180': 'MSG:37.180',
#  '37.181': 'MSG:37.181',
#  '37.182': 'MSG:37.182',
#  '37.183': 'MSG:37.183',
#  '37.184': 'MSG:37.184',
#  '37.185': 'MSG:37.185',
#  '37.186': 'MSG:37.186',
#  '38.187': 'MSG:38.187',
#  '38.188': 'MSG:38.188',
#  '38.189': 'MSG:38.189',
#  '38.190': 'MSG:38.190',
#  '38.191': 'MSG:38.191',
#  '38.192': 'MSG:38.192',
#  '38.193': 'MSG:38.193',
#  '38.194': 'MSG:38.194',
#  '39.195': 'MSG:39.195',
#  '39.196': 'MSG:39.196',
#  '39.197': 'MSG:39.197',
#  '39.198': 'MSG:39.198',
#  '39.199': 'MSG:39.199',
#  '39.200': 'MSG:39.200',
#  '39.201': 'MSG:39.201',
#  '39.202': 'MSG:39.202',
#  '40.203': 'MSG:40.203',
#  '40.204': 'MSG:40.204',
#  '40.205': 'MSG:40.205',
#  '40.206': 'MSG:40.206',
#  '40.207': 'MSG:40.207',
#  '40.208': 'MSG:40.208',
#  '40.209': 'MSG:40.209',
#  '40.210': 'MSG:40.210',
#  '41.211': 'MSG:41.211',
#  '41.212': 'MSG:41.212',
#  '41.213': 'MSG:41.213',
#  '41.214': 'MSG:41.214',
#  '41.215': 'MSG:41.215',
#  '41.216': 'MSG:41.216',
#  '41.217': 'MSG:41.217',
#  '41.218': 'MSG:41.218',
#  '42.219': 'MSG:42.219',
#  '42.220': 'MSG:42.220',
#  '42.221': 'MSG:42.221',
#  '42.222': 'MSG:42.222',
#  '42.223': 'MSG:42.223',
#  '43.224': 'MSG:43.224',
#  '43.225': 'MSG:43.225',
#  '43.226': 'MSG:43.226',
#  '43.227': 'MSG:43.227',
#  '43.228': 'MSG:43.228',
#  '44.229': 'MSG:44.229',
#  '44.230': 'MSG:44.230',
#  '44.231': 'MSG:44.231',
#  '44.232': 'MSG:44.232',
#  '44.233': 'MSG:44.233',
#  '44.234': 'MSG:44.234',
#  '45.235': 'MSG:45.235',
#  '45.236': 'MSG:45.236',
#  '45.237': 'MSG:45.237',
#  '45.238': 'MSG:45.238',
#  '45.239': 'MSG:45.239',
#  '45.240': 'MSG:45.240',
#  '46.241': 'MSG:46.241',
#  '46.242': 'MSG:46.242',
#  '46.243': 'MSG:46.243',
#  '46.244': 'MSG:46.244',
#  '46.245': 'MSG:46.245',
#  '46.246': 'MSG:46.246',
#  '46.247': 'MSG:46.247',
#  '46.248': 'MSG:46.248',
#  '47.249': 'MSG:47.249',
#  '47.250': 'MSG:47.250',
#  '47.251': 'MSG:47.251',
#  '47.252': 'MSG:47.252',
#  '47.253': 'MSG:47.253',
#  '47.254': 'MSG:47.254',
#  '47.255': 'MSG:47.255',
#  '47.256': 'MSG:47.256',
#  '48.257': 'MSG:48.257',
#  '48.258': 'MSG:48.258',
#  '48.259': 'MSG:48.259',
#  '48.260': 'MSG:48.260',
#  '48.261': 'MSG:48.261',
#  '48.262': 'MSG:48.262',
#  '48.263': 'MSG:48.263',
#  '48.264': 'MSG:48.264',
#  '49.265': 'MSG:49.265',
#  '49.266': 'MSG:49.266',
#  '49.267': 'MSG:49.267',
#  '49.268': 'MSG:49.268',
#  '49.269': 'MSG:49.269',
#  '49.270': 'MSG:49.270',
#  '49.271': 'MSG:49.271',
#  '49.272': 'MSG:49.272',
#  '49.273': 'MSG:49.273',
#  '49.274': 'MSG:49.274',
#  '49.275': 'MSG:49.275',
#  '49.276': 'MSG:49.276',
#  '50.277': 'MSG:50.277',
#  '50.278': 'MSG:50.278',
#  '50.279': 'MSG:50.279',
#  '50.280': 'MSG:50.280',
#  '50.281': 'MSG:50.281',
#  '50.282': 'MSG:50.282',
#  '50.283': 'MSG:50.283',
#  '50.284': 'MSG:50.284',
#  '50.285': 'MSG:50.285',
#  '50.286': 'MSG:50.286',
#  '50.287': 'MSG:50.287',
#  '50.288': 'MSG:50.288',
#  '51.289': 'MSG:51.289',
#  '51.290': 'MSG:51.290',
#  '51.291': 'MSG:51.291',
#  '51.292': 'MSG:51.292',
#  '51.293': 'MSG:51.293',
#  '51.294': 'MSG:51.294',
#  '51.295': 'MSG:51.295',
#  '51.296': 'MSG:51.296',
#  '51.297': 'MSG:51.297',
#  '51.298': 'MSG:51.298',
#  '51.299': 'MSG:51.299',
#  '51.300': 'MSG:51.300',
#  '51.301': 'MSG:51.301',
#  '51.302': 'MSG:51.302',
#  '51.303': 'MSG:51.303',
#  '51.304': 'MSG:51.304',
#  '52.305': 'MSG:52.305',
#  '52.306': 'MSG:52.306',
#  '52.307': 'MSG:52.307',
#  '52.308': 'MSG:52.308',
#  '52.309': 'MSG:52.309',
#  '52.310': 'MSG:52.310',
#  '52.311': 'MSG:52.311',
#  '52.312': 'MSG:52.312',
#  '52.313': 'MSG:52.313',
#  '52.314': 'MSG:52.314',
#  '52.315': 'MSG:52.315',
#  '52.316': 'MSG:52.316',
#  '52.317': 'MSG:52.317',
#  '52.318': 'MSG:52.318',
#  '52.319': 'MSG:52.319',
#  '52.320': 'MSG:52.320',
#  '53.321': 'MSG:53.321',
#  '53.322': 'MSG:53.322',
#  '53.323': 'MSG:53.323',
#  '53.324': 'MSG:53.324',
#  '53.325': 'MSG:53.325',
#  '53.326': 'MSG:53.326',
#  '53.327': 'MSG:53.327',
#  '53.328': 'MSG:53.328',
#  '53.329': 'MSG:53.329',
#  '53.330': 'MSG:53.330',
#  '53.331': 'MSG:53.331',
#  '53.332': 'MSG:53.332',
#  '53.333': 'MSG:53.333',
#  '53.334': 'MSG:53.334',
#  '53.335': 'MSG:53.335',
#  '53.336': 'MSG:53.336',
#  '54.337': 'MSG:54.337',
#  '54.338': 'MSG:54.338',
#  '54.339': 'MSG:54.339',
#  '54.340': 'MSG:54.340',
#  '54.341': 'MSG:54.341',
#  '54.342': 'MSG:54.342',
#  '54.343': 'MSG:54.343',
#  '54.344': 'MSG:54.344',
#  '54.345': 'MSG:54.345',
#  '54.346': 'MSG:54.346',
#  '54.347': 'MSG:54.347',
#  '54.348': 'MSG:54.348',
#  '54.349': 'MSG:54.349',
#  '54.350': 'MSG:54.350',
#  '54.351': 'MSG:54.351',
#  '54.352': 'MSG:54.352',
#  '55.353': 'MSG:55.353',
#  '55.354': 'MSG:55.354',
#  '55.355': 'MSG:55.355',
#  '55.356': 'MSG:55.356',
#  '55.357': 'MSG:55.357',
#  '55.358': 'MSG:55.358',
#  '55.359': 'MSG:55.359',
#  '55.360': 'MSG:55.360',
#  '55.361': 'MSG:55.361',
#  '55.362': 'MSG:55.362',
#  '55.363': 'MSG:55.363',
#  '55.364': 'MSG:55.364',
#  '56.365': 'MSG:56.365',
#  '56.366': 'MSG:56.366',
#  '56.367': 'MSG:56.367',
#  '56.368': 'MSG:56.368',
#  '56.369': 'MSG:56.369',
#  '56.370': 'MSG:56.370',
#  '56.371': 'MSG:56.371',
#  '56.372': 'MSG:56.372',
#  '56.373': 'MSG:56.373',
#  '56.374': 'MSG:56.374',
#  '56.375': 'MSG:56.375',
#  '56.376': 'MSG:56.376',
#  '57.377': 'MSG:57.377',
#  '57.378': 'MSG:57.378',
#  '57.379': 'MSG:57.379',
#  '57.380': 'MSG:57.380',
#  '57.381': 'MSG:57.381',
#  '57.382': 'MSG:57.382',
#  '57.383': 'MSG:57.383',
#  '57.384': 'MSG:57.384',
#  '57.385': 'MSG:57.385',
#  '57.386': 'MSG:57.386',
#  '57.387': 'MSG:57.387',
#  '57.388': 'MSG:57.388',
#  '57.389': 'MSG:57.389',
#  '57.390': 'MSG:57.390',
#  '57.391': 'MSG:57.391',
#  '57.392': 'MSG:57.392',
#  '58.393': 'MSG:58.393',
#  '58.394': 'MSG:58.394',
#  '58.395': 'MSG:58.395',
#  '58.396': 'MSG:58.396',
#  '58.397': 'MSG:58.397',
#  '58.398': 'MSG:58.398',
#  '58.399': 'MSG:58.399',
#  '58.400': 'MSG:58.400',
#  '58.401': 'MSG:58.401',
#  '58.402': 'MSG:58.402',
#  '58.403': 'MSG:58.403',
#  '58.404': 'MSG:58.404',
#  '59.405': 'MSG:59.405',
#  '59.406': 'MSG:59.406',
#  '59.407': 'MSG:59.407',
#  '59.408': 'MSG:59.408',
#  '59.409': 'MSG:59.409',
#  '59.410': 'MSG:59.410',
#  '59.411': 'MSG:59.411',
#  '59.412': 'MSG:59.412',
#  '59.413': 'MSG:59.413',
#  '59.414': 'MSG:59.414',
#  '59.415': 'MSG:59.415',
#  '59.416': 'MSG:59.416',
#  '60.417': 'MSG:60.417',
#  '60.418': 'MSG:60.418',
#  '60.419': 'MSG:60.419',
#  '60.420': 'MSG:60.420',
#  '60.421': 'MSG:60.421',
#  '60.422': 'MSG:60.422',
#  '60.423': 'MSG:60.423',
#  '60.424': 'MSG:60.424',
#  '60.425': 'MSG:60.425',
#  '60.426': 'MSG:60.426',
#  '60.427': 'MSG:60.427',
#  '60.428': 'MSG:60.428',
#  '60.429': 'MSG:60.429',
#  '60.430': 'MSG:60.430',
#  '60.431': 'MSG:60.431',
#  '60.432': 'MSG:60.432',
#  '61.433': 'MSG:61.433',
#  '61.434': 'MSG:61.434',
#  '61.435': 'MSG:61.435',
#  '61.436': 'MSG:61.436',
#  '61.437': 'MSG:61.437',
#  '61.438': 'MSG:61.438',
#  '61.439': 'MSG:61.439',
#  '61.440': 'MSG:61.440',
#  '62.441': 'MSG:62.441',
#  '62.442': 'MSG:62.442',
#  '62.443': 'MSG:62.443',
#  '62.444': 'MSG:62.444',
#  '62.445': 'MSG:62.445',
#  '62.446': 'MSG:62.446',
#  '62.447': 'MSG:62.447',
#  '62.448': 'MSG:62.448',
#  '62.449': 'MSG:62.449',
#  '62.450': 'MSG:62.450',
#  '62.451': 'MSG:62.451',
#  '62.452': 'MSG:62.452',
#  '62.453': 'MSG:62.453',
#  '62.454': 'MSG:62.454',
#  '62.455': 'MSG:62.455',
#  '62.456': 'MSG:62.456',
#  '63.457': 'MSG:63.457',
#  '63.458': 'MSG:63.458',
#  '63.459': 'MSG:63.459',
#  '63.460': 'MSG:63.460',
#  '63.461': 'MSG:63.461',
#  '63.462': 'MSG:63.462',
#  '63.463': 'MSG:63.463',
#  '63.464': 'MSG:63.464',
#  '63.465': 'MSG:63.465',
#  '63.466': 'MSG:63.466',
#  '63.467': 'MSG:63.467',
#  '63.468': 'MSG:63.468',
#  ...}

# %%
info["tag"]
# Out:
# {'PG:1': 'C1',
#  'PG:2': 'Ci',
#  'PG:3': 'C2',
#  'PG:4': 'Cs',
#  'PG:5': 'C2h',
#  'PG:6': 'D2',
#  'PG:7': 'C2v',
#  'PG:8': 'D2h',
#  'PG:9': 'C4',
#  'PG:10': 'S4',
#  'PG:11': 'C4h',
#  'PG:12': 'D4',
#  'PG:13': 'C4v',
#  'PG:14': 'D2d',
#  'PG:15': 'D4h',
#  'PG:16': 'C3',
#  'PG:17': 'C3i',
#  'PG:18': 'D3',
#  'PG:19': 'C3v',
#  'PG:20': 'D3d',
#  'PG:21': 'C6',
#  'PG:22': 'C3h',
#  'PG:23': 'C6h',
#  'PG:24': 'D6',
#  'PG:25': 'C6v',
#  'PG:26': 'D3h',
#  'PG:27': 'D6h',
#  'PG:28': 'T',
#  'PG:29': 'Th',
#  'PG:30': 'O',
#  'PG:31': 'Td',
#  'PG:32': 'Oh',
#  'PG:33': 'D2d-1',
#  'PG:34': 'D3-1',
#  'PG:35': 'C3v-1',
#  'PG:36': 'D3d-1',
#  'PG:37': 'D3h-1',
#  'PG:38': 'C4-c',
#  'PG:39': 'S4-c',
#  'PG:40': 'C4h-c',
#  'PG:41': 'C3-c',
#  'PG:42': 'C3i-c',
#  'PG:43': 'C6-c',
#  'PG:44': 'C3h-c',
#  'PG:45': 'C6h-c',
#  'PG:46': 'T-c',
#  'PG:47': 'Th-c',
#  'SG:1': 'C1^1',
#  'SG:2': 'Ci^1',
#  'SG:3': 'C2^1',
#  'SG:4': 'C2^2',
#  'SG:5': 'C2^3',
#  'SG:6': 'Cs^1',
#  'SG:7': 'Cs^2',
#  'SG:8': 'Cs^3',
#  'SG:9': 'Cs^4',
#  'SG:10': 'C2h^1',
#  'SG:11': 'C2h^2',
#  'SG:12': 'C2h^3',
#  'SG:13': 'C2h^4',
#  'SG:14': 'C2h^5',
#  'SG:15': 'C2h^6',
#  'SG:16': 'D2^1',
#  'SG:17': 'D2^2',
#  'SG:18': 'D2^3',
#  'SG:19': 'D2^4',
#  'SG:20': 'D2^5',
#  'SG:21': 'D2^6',
#  'SG:22': 'D2^7',
#  'SG:23': 'D2^8',
#  'SG:24': 'D2^9',
#  'SG:25': 'C2v^1',
#  'SG:26': 'C2v^2',
#  'SG:27': 'C2v^3',
#  'SG:28': 'C2v^4',
#  'SG:29': 'C2v^5',
#  'SG:30': 'C2v^6',
#  'SG:31': 'C2v^7',
#  'SG:32': 'C2v^8',
#  'SG:33': 'C2v^9',
#  'SG:34': 'C2v^10',
#  'SG:35': 'C2v^11',
#  'SG:36': 'C2v^12',
#  'SG:37': 'C2v^13',
#  'SG:38': 'C2v^14',
#  'SG:39': 'C2v^15',
#  'SG:40': 'C2v^16',
#  'SG:41': 'C2v^17',
#  'SG:42': 'C2v^18',
#  'SG:43': 'C2v^19',
#  'SG:44': 'C2v^20',
#  'SG:45': 'C2v^21',
#  'SG:46': 'C2v^22',
#  'SG:47': 'D2h^1',
#  'SG:48': 'D2h^2',
#  'SG:49': 'D2h^3',
#  'SG:50': 'D2h^4',
#  'SG:51': 'D2h^5',
#  'SG:52': 'D2h^6',
#  'SG:53': 'D2h^7',
#  'SG:54': 'D2h^8',
#  'SG:55': 'D2h^9',
#  'SG:56': 'D2h^10',
#  'SG:57': 'D2h^11',
#  'SG:58': 'D2h^12',
#  'SG:59': 'D2h^13',
#  'SG:60': 'D2h^14',
#  'SG:61': 'D2h^15',
#  'SG:62': 'D2h^16',
#  'SG:63': 'D2h^17',
#  'SG:64': 'D2h^18',
#  'SG:65': 'D2h^19',
#  'SG:66': 'D2h^20',
#  'SG:67': 'D2h^21',
#  'SG:68': 'D2h^22',
#  'SG:69': 'D2h^23',
#  'SG:70': 'D2h^24',
#  'SG:71': 'D2h^25',
#  'SG:72': 'D2h^26',
#  'SG:73': 'D2h^27',
#  'SG:74': 'D2h^28',
#  'SG:75': 'C4^1',
#  'SG:76': 'C4^2',
#  'SG:77': 'C4^3',
#  'SG:78': 'C4^4',
#  'SG:79': 'C4^5',
#  'SG:80': 'C4^6',
#  'SG:81': 'S4^1',
#  'SG:82': 'S4^2',
#  'SG:83': 'C4h^1',
#  'SG:84': 'C4h^2',
#  'SG:85': 'C4h^3',
#  'SG:86': 'C4h^4',
#  'SG:87': 'C4h^5',
#  'SG:88': 'C4h^6',
#  'SG:89': 'D4^1',
#  'SG:90': 'D4^2',
#  'SG:91': 'D4^3',
#  'SG:92': 'D4^4',
#  'SG:93': 'D4^5',
#  'SG:94': 'D4^6',
#  'SG:95': 'D4^7',
#  'SG:96': 'D4^8',
#  'SG:97': 'D4^9',
#  'SG:98': 'D4^10',
#  'SG:99': 'C4v^1',
#  'SG:100': 'C4v^2',
#  'SG:101': 'C4v^3',
#  'SG:102': 'C4v^4',
#  'SG:103': 'C4v^5',
#  'SG:104': 'C4v^6',
#  'SG:105': 'C4v^7',
#  'SG:106': 'C4v^8',
#  'SG:107': 'C4v^9',
#  'SG:108': 'C4v^10',
#  'SG:109': 'C4v^11',
#  'SG:110': 'C4v^12',
#  'SG:111': 'D2d^1',
#  'SG:112': 'D2d^2',
#  'SG:113': 'D2d^3',
#  'SG:114': 'D2d^4',
#  'SG:115': 'D2d^5',
#  'SG:116': 'D2d^6',
#  'SG:117': 'D2d^7',
#  'SG:118': 'D2d^8',
#  'SG:119': 'D2d^9',
#  'SG:120': 'D2d^10',
#  'SG:121': 'D2d^11',
#  'SG:122': 'D2d^12',
#  'SG:123': 'D4h^1',
#  'SG:124': 'D4h^2',
#  'SG:125': 'D4h^3',
#  'SG:126': 'D4h^4',
#  'SG:127': 'D4h^5',
#  'SG:128': 'D4h^6',
#  'SG:129': 'D4h^7',
#  'SG:130': 'D4h^8',
#  'SG:131': 'D4h^9',
#  'SG:132': 'D4h^10',
#  'SG:133': 'D4h^11',
#  'SG:134': 'D4h^12',
#  'SG:135': 'D4h^13',
#  'SG:136': 'D4h^14',
#  'SG:137': 'D4h^15',
#  'SG:138': 'D4h^16',
#  'SG:139': 'D4h^17',
#  'SG:140': 'D4h^18',
#  'SG:141': 'D4h^19',
#  'SG:142': 'D4h^20',
#  'SG:143': 'C3^1',
#  'SG:144': 'C3^2',
#  'SG:145': 'C3^3',
#  'SG:146': 'C3^4',
#  'SG:147': 'C3i^1',
#  'SG:148': 'C3i^2',
#  'SG:149': 'D3^1',
#  'SG:150': 'D3^2',
#  'SG:151': 'D3^3',
#  'SG:152': 'D3^4',
#  'SG:153': 'D3^5',
#  'SG:154': 'D3^6',
#  'SG:155': 'D3^7',
#  'SG:156': 'C3v^1',
#  'SG:157': 'C3v^2',
#  'SG:158': 'C3v^3',
#  'SG:159': 'C3v^4',
#  'SG:160': 'C3v^5',
#  'SG:161': 'C3v^6',
#  'SG:162': 'D3d^1',
#  'SG:163': 'D3d^2',
#  'SG:164': 'D3d^3',
#  'SG:165': 'D3d^4',
#  'SG:166': 'D3d^5',
#  'SG:167': 'D3d^6',
#  'SG:168': 'C6^1',
#  'SG:169': 'C6^2',
#  'SG:170': 'C6^3',
#  'SG:171': 'C6^4',
#  'SG:172': 'C6^5',
#  'SG:173': 'C6^6',
#  'SG:174': 'C3h^1',
#  'SG:175': 'C6h^1',
#  'SG:176': 'C6h^2',
#  'SG:177': 'D6^1',
#  'SG:178': 'D6^2',
#  'SG:179': 'D6^3',
#  'SG:180': 'D6^4',
#  'SG:181': 'D6^5',
#  'SG:182': 'D6^6',
#  'SG:183': 'C6v^1',
#  'SG:184': 'C6v^2',
#  'SG:185': 'C6v^3',
#  'SG:186': 'C6v^4',
#  'SG:187': 'D3h^1',
#  'SG:188': 'D3h^2',
#  'SG:189': 'D3h^3',
#  'SG:190': 'D3h^4',
#  'SG:191': 'D6h^1',
#  'SG:192': 'D6h^2',
#  'SG:193': 'D6h^3',
#  'SG:194': 'D6h^4',
#  'SG:195': 'T^1',
#  'SG:196': 'T^2',
#  'SG:197': 'T^3',
#  'SG:198': 'T^4',
#  'SG:199': 'T^5',
#  'SG:200': 'Th^1',
#  'SG:201': 'Th^2',
#  'SG:202': 'Th^3',
#  'SG:203': 'Th^4',
#  'SG:204': 'Th^5',
#  'SG:205': 'Th^6',
#  'SG:206': 'Th^7',
#  'SG:207': 'O^1',
#  'SG:208': 'O^2',
#  'SG:209': 'O^3',
#  'SG:210': 'O^4',
#  'SG:211': 'O^5',
#  'SG:212': 'O^6',
#  'SG:213': 'O^7',
#  'SG:214': 'O^8',
#  'SG:215': 'Td^1',
#  'SG:216': 'Td^2',
#  'SG:217': 'Td^3',
#  'SG:218': 'Td^4',
#  'SG:219': 'Td^5',
#  'SG:220': 'Td^6',
#  'SG:221': 'Oh^1',
#  'SG:222': 'Oh^2',
#  'SG:223': 'Oh^3',
#  'SG:224': 'Oh^4',
#  'SG:225': 'Oh^5',
#  'SG:226': 'Oh^6',
#  'SG:227': 'Oh^7',
#  'SG:228': 'Oh^8',
#  'SG:229': 'Oh^9',
#  'SG:230': 'Oh^10',
#  'MPG:1.1.1': '1.1.1',
#  'MPG:1.2.2': '1.2.2',
#  'MPG:2.1.3': '2.1.3',
#  'MPG:2.2.4': '2.2.4',
#  'MPG:2.3.5': '2.3.5',
#  'MPG:3.1.6': '3.1.6',
#  'MPG:3.2.7': '3.2.7',
#  'MPG:3.3.8': '3.3.8',
#  'MPG:4.1.9': '4.1.9',
#  'MPG:4.2.10': '4.2.10',
#  'MPG:4.3.11': '4.3.11',
#  'MPG:5.1.12': '5.1.12',
#  'MPG:5.2.13': '5.2.13',
#  'MPG:5.3.14': '5.3.14',
#  'MPG:5.4.15': '5.4.15',
#  'MPG:5.5.16': '5.5.16',
#  'MPG:6.1.17': '6.1.17',
#  'MPG:6.2.18': '6.2.18',
#  'MPG:6.3.19': '6.3.19',
#  'MPG:6.4.123': '6.4.123',
#  'MPG:7.1.20': '7.1.20',
#  'MPG:7.2.21': '7.2.21',
#  'MPG:7.3.22': '7.3.22',
#  'MPG:7.4.23': '7.4.23',
#  'MPG:7.5.124': '7.5.124',
#  'MPG:8.1.24': '8.1.24',
#  'MPG:8.2.25': '8.2.25',
#  'MPG:8.3.26': '8.3.26',
#  'MPG:8.4.27': '8.4.27',
#  'MPG:8.5.28': '8.5.28',
#  'MPG:8.6.125': '8.6.125',
#  'MPG:8.7.126': '8.7.126',
#  'MPG:8.8.127': '8.8.127',
#  'MPG:8.9.128': '8.9.128',
#  'MPG:9.1.29': '9.1.29',
#  'MPG:9.2.30': '9.2.30',
#  'MPG:9.3.31': '9.3.31',
#  'MPG:10.1.32': '10.1.32',
#  'MPG:10.2.33': '10.2.33',
#  'MPG:10.3.34': '10.3.34',
#  'MPG:11.1.35': '11.1.35',
#  'MPG:11.2.36': '11.2.36',
#  'MPG:11.3.37': '11.3.37',
#  'MPG:11.4.38': '11.4.38',
#  'MPG:11.5.39': '11.5.39',
#  'MPG:12.1.40': '12.1.40',
#  'MPG:12.2.41': '12.2.41',
#  'MPG:12.3.42': '12.3.42',
#  'MPG:12.4.43': '12.4.43',
#  'MPG:12.5.129': '12.5.129',
#  'MPG:13.1.44': '13.1.44',
#  'MPG:13.2.45': '13.2.45',
#  'MPG:13.3.46': '13.3.46',
#  'MPG:13.4.47': '13.4.47',
#  'MPG:13.5.130': '13.5.130',
#  'MPG:14.1.48': '14.1.48',
#  'MPG:14.2.49': '14.2.49',
#  'MPG:14.3.50': '14.3.50',
#  'MPG:14.4.51': '14.4.51',
#  'MPG:14.5.52': '14.5.52',
#  'MPG:15.1.53': '15.1.53',
#  'MPG:15.2.54': '15.2.54',
#  'MPG:15.3.55': '15.3.55',
#  'MPG:15.4.56': '15.4.56',
#  'MPG:15.5.57': '15.5.57',
#  'MPG:15.6.58': '15.6.58',
#  'MPG:15.7.59': '15.7.59',
#  'MPG:15.8.136': '15.8.136',
#  'MPG:15.9.137': '15.9.137',
#  'MPG:16.1.60': '16.1.60',
#  'MPG:16.2.61': '16.2.61',
#  'MPG:17.1.62': '17.1.62',
#  'MPG:17.2.63': '17.2.63',
#  'MPG:17.3.64': '17.3.64',
#  'MPG:18.1.65': '18.1.65',
#  'MPG:18.2.66': '18.2.66',
#  'MPG:18.3.67': '18.3.67',
#  'MPG:19.1.68': '19.1.68',
#  'MPG:19.2.69': '19.2.69',
#  'MPG:19.3.70': '19.3.70',
#  'MPG:20.1.71': '20.1.71',
#  'MPG:20.2.72': '20.2.72',
#  'MPG:20.3.73': '20.3.73',
#  'MPG:20.4.74': '20.4.74',
#  'MPG:20.5.75': '20.5.75',
#  'MPG:21.1.76': '21.1.76',
#  'MPG:21.2.77': '21.2.77',
#  'MPG:21.3.78': '21.3.78',
#  'MPG:22.1.79': '22.1.79',
#  'MPG:22.2.80': '22.2.80',
#  'MPG:22.3.81': '22.3.81',
#  'MPG:23.1.82': '23.1.82',
#  'MPG:23.2.83': '23.2.83',
#  'MPG:23.3.84': '23.3.84',
#  'MPG:23.4.85': '23.4.85',
#  'MPG:23.5.86': '23.5.86',
#  'MPG:24.1.87': '24.1.87',
#  'MPG:24.2.88': '24.2.88',
#  'MPG:24.3.89': '24.3.89',
#  'MPG:24.4.90': '24.4.90',
#  'MPG:24.5.149': '24.5.149',
#  'MPG:25.1.91': '25.1.91',
#  'MPG:25.2.92': '25.2.92',
#  'MPG:25.3.93': '25.3.93',
#  'MPG:25.4.94': '25.4.94',
#  'MPG:25.5.150': '25.5.150',
#  'MPG:26.1.95': '26.1.95',
#  'MPG:26.2.96': '26.2.96',
#  'MPG:26.3.97': '26.3.97',
#  'MPG:26.4.98': '26.4.98',
#  'MPG:26.5.99': '26.5.99',
#  'MPG:27.1.100': '27.1.100',
#  'MPG:27.2.101': '27.2.101',
#  'MPG:27.3.102': '27.3.102',
#  'MPG:27.4.103': '27.4.103',
#  'MPG:27.5.104': '27.5.104',
#  'MPG:27.6.105': '27.6.105',
#  'MPG:27.7.106': '27.7.106',
#  'MPG:27.8.156': '27.8.156',
#  'MPG:27.9.157': '27.9.157',
#  'MPG:28.1.107': '28.1.107',
#  'MPG:28.2.108': '28.2.108',
#  'MPG:29.1.109': '29.1.109',
#  'MPG:29.2.110': '29.2.110',
#  'MPG:29.3.111': '29.3.111',
#  'MPG:30.1.112': '30.1.112',
#  'MPG:30.2.113': '30.2.113',
#  'MPG:30.3.114': '30.3.114',
#  'MPG:31.1.115': '31.1.115',
#  'MPG:31.2.116': '31.2.116',
#  'MPG:31.3.117': '31.3.117',
#  'MPG:32.1.118': '32.1.118',
#  'MPG:32.2.119': '32.2.119',
#  'MPG:32.3.120': '32.3.120',
#  'MPG:32.4.121': '32.4.121',
#  'MPG:32.5.122': '32.5.122',
#  'MPG:33.1.131': '33.1.131',
#  'MPG:33.2.132': '33.2.132',
#  'MPG:33.3.133': '33.3.133',
#  'MPG:33.4.134': '33.4.134',
#  'MPG:33.5.135': '33.5.135',
#  'MPG:34.1.138': '34.1.138',
#  'MPG:34.2.139': '34.2.139',
#  'MPG:34.3.140': '34.3.140',
#  'MPG:35.1.141': '35.1.141',
#  'MPG:35.2.142': '35.2.142',
#  'MPG:35.3.143': '35.3.143',
#  'MPG:36.1.144': '36.1.144',
#  'MPG:36.2.145': '36.2.145',
#  'MPG:36.3.146': '36.3.146',
#  'MPG:36.4.147': '36.4.147',
#  'MPG:36.5.148': '36.5.148',
#  'MPG:37.1.151': '37.1.151',
#  'MPG:37.2.152': '37.2.152',
#  'MPG:37.3.153': '37.3.153',
#  'MPG:37.4.154': '37.4.154',
#  'MPG:37.5.155': '37.5.155',
#  'MSG:1.1': '1.1',
#  'MSG:1.2': '1.2',
#  'MSG:1.3': '1.3',
#  'MSG:2.4': '2.4',
#  'MSG:2.5': '2.5',
#  'MSG:2.6': '2.6',
#  'MSG:2.7': '2.7',
#  'MSG:3.1': '3.1',
#  'MSG:3.2': '3.2',
#  'MSG:3.3': '3.3',
#  'MSG:3.4': '3.4',
#  'MSG:3.5': '3.5',
#  'MSG:3.6': '3.6',
#  'MSG:4.7': '4.7',
#  'MSG:4.8': '4.8',
#  'MSG:4.9': '4.9',
#  'MSG:4.10': '4.10',
#  'MSG:4.11': '4.11',
#  'MSG:4.12': '4.12',
#  'MSG:5.13': '5.13',
#  'MSG:5.14': '5.14',
#  'MSG:5.15': '5.15',
#  'MSG:5.16': '5.16',
#  'MSG:5.17': '5.17',
#  'MSG:6.18': '6.18',
#  'MSG:6.19': '6.19',
#  'MSG:6.20': '6.20',
#  'MSG:6.21': '6.21',
#  'MSG:6.22': '6.22',
#  'MSG:6.23': '6.23',
#  'MSG:7.24': '7.24',
#  'MSG:7.25': '7.25',
#  'MSG:7.26': '7.26',
#  'MSG:7.27': '7.27',
#  'MSG:7.28': '7.28',
#  'MSG:7.29': '7.29',
#  'MSG:7.30': '7.30',
#  'MSG:7.31': '7.31',
#  'MSG:8.32': '8.32',
#  'MSG:8.33': '8.33',
#  'MSG:8.34': '8.34',
#  'MSG:8.35': '8.35',
#  'MSG:8.36': '8.36',
#  'MSG:9.37': '9.37',
#  'MSG:9.38': '9.38',
#  'MSG:9.39': '9.39',
#  'MSG:9.40': '9.40',
#  'MSG:9.41': '9.41',
#  'MSG:10.42': '10.42',
#  'MSG:10.43': '10.43',
#  'MSG:10.44': '10.44',
#  'MSG:10.45': '10.45',
#  'MSG:10.46': '10.46',
#  'MSG:10.47': '10.47',
#  'MSG:10.48': '10.48',
#  'MSG:10.49': '10.49',
#  'MSG:11.50': '11.50',
#  'MSG:11.51': '11.51',
#  'MSG:11.52': '11.52',
#  'MSG:11.53': '11.53',
#  'MSG:11.54': '11.54',
#  'MSG:11.55': '11.55',
#  'MSG:11.56': '11.56',
#  'MSG:11.57': '11.57',
#  'MSG:12.58': '12.58',
#  'MSG:12.59': '12.59',
#  'MSG:12.60': '12.60',
#  'MSG:12.61': '12.61',
#  'MSG:12.62': '12.62',
#  'MSG:12.63': '12.63',
#  'MSG:12.64': '12.64',
#  'MSG:13.65': '13.65',
#  'MSG:13.66': '13.66',
#  'MSG:13.67': '13.67',
#  'MSG:13.68': '13.68',
#  'MSG:13.69': '13.69',
#  'MSG:13.70': '13.70',
#  'MSG:13.71': '13.71',
#  'MSG:13.72': '13.72',
#  'MSG:13.73': '13.73',
#  'MSG:13.74': '13.74',
#  'MSG:14.75': '14.75',
#  'MSG:14.76': '14.76',
#  'MSG:14.77': '14.77',
#  'MSG:14.78': '14.78',
#  'MSG:14.79': '14.79',
#  'MSG:14.80': '14.80',
#  'MSG:14.81': '14.81',
#  'MSG:14.82': '14.82',
#  'MSG:14.83': '14.83',
#  'MSG:14.84': '14.84',
#  'MSG:15.85': '15.85',
#  'MSG:15.86': '15.86',
#  'MSG:15.87': '15.87',
#  'MSG:15.88': '15.88',
#  'MSG:15.89': '15.89',
#  'MSG:15.90': '15.90',
#  'MSG:15.91': '15.91',
#  'MSG:16.1': '16.1',
#  'MSG:16.2': '16.2',
#  'MSG:16.3': '16.3',
#  'MSG:16.4': '16.4',
#  'MSG:16.5': '16.5',
#  'MSG:16.6': '16.6',
#  'MSG:17.7': '17.7',
#  'MSG:17.8': '17.8',
#  'MSG:17.9': '17.9',
#  'MSG:17.10': '17.10',
#  'MSG:17.11': '17.11',
#  'MSG:17.12': '17.12',
#  'MSG:17.13': '17.13',
#  'MSG:17.14': '17.14',
#  'MSG:17.15': '17.15',
#  'MSG:18.16': '18.16',
#  'MSG:18.17': '18.17',
#  'MSG:18.18': '18.18',
#  'MSG:18.19': '18.19',
#  'MSG:18.20': '18.20',
#  'MSG:18.21': '18.21',
#  'MSG:18.22': '18.22',
#  'MSG:18.23': '18.23',
#  'MSG:18.24': '18.24',
#  'MSG:19.25': '19.25',
#  'MSG:19.26': '19.26',
#  'MSG:19.27': '19.27',
#  'MSG:19.28': '19.28',
#  'MSG:19.29': '19.29',
#  'MSG:19.30': '19.30',
#  'MSG:20.31': '20.31',
#  'MSG:20.32': '20.32',
#  'MSG:20.33': '20.33',
#  'MSG:20.34': '20.34',
#  'MSG:20.35': '20.35',
#  'MSG:20.36': '20.36',
#  'MSG:20.37': '20.37',
#  'MSG:21.38': '21.38',
#  'MSG:21.39': '21.39',
#  'MSG:21.40': '21.40',
#  'MSG:21.41': '21.41',
#  'MSG:21.42': '21.42',
#  'MSG:21.43': '21.43',
#  'MSG:21.44': '21.44',
#  'MSG:22.45': '22.45',
#  'MSG:22.46': '22.46',
#  'MSG:22.47': '22.47',
#  'MSG:22.48': '22.48',
#  'MSG:23.49': '23.49',
#  'MSG:23.50': '23.50',
#  'MSG:23.51': '23.51',
#  'MSG:23.52': '23.52',
#  'MSG:24.53': '24.53',
#  'MSG:24.54': '24.54',
#  'MSG:24.55': '24.55',
#  'MSG:24.56': '24.56',
#  'MSG:25.57': '25.57',
#  'MSG:25.58': '25.58',
#  'MSG:25.59': '25.59',
#  'MSG:25.60': '25.60',
#  'MSG:25.61': '25.61',
#  'MSG:25.62': '25.62',
#  'MSG:25.63': '25.63',
#  'MSG:25.64': '25.64',
#  'MSG:25.65': '25.65',
#  'MSG:26.66': '26.66',
#  'MSG:26.67': '26.67',
#  'MSG:26.68': '26.68',
#  'MSG:26.69': '26.69',
#  'MSG:26.70': '26.70',
#  'MSG:26.71': '26.71',
#  'MSG:26.72': '26.72',
#  'MSG:26.73': '26.73',
#  'MSG:26.74': '26.74',
#  'MSG:26.75': '26.75',
#  'MSG:26.76': '26.76',
#  'MSG:26.77': '26.77',
#  'MSG:27.78': '27.78',
#  'MSG:27.79': '27.79',
#  'MSG:27.80': '27.80',
#  'MSG:27.81': '27.81',
#  'MSG:27.82': '27.82',
#  'MSG:27.83': '27.83',
#  'MSG:27.84': '27.84',
#  'MSG:27.85': '27.85',
#  'MSG:27.86': '27.86',
#  'MSG:28.87': '28.87',
#  'MSG:28.88': '28.88',
#  'MSG:28.89': '28.89',
#  'MSG:28.90': '28.90',
#  'MSG:28.91': '28.91',
#  'MSG:28.92': '28.92',
#  'MSG:28.93': '28.93',
#  'MSG:28.94': '28.94',
#  'MSG:28.95': '28.95',
#  'MSG:28.96': '28.96',
#  'MSG:28.97': '28.97',
#  'MSG:28.98': '28.98',
#  'MSG:29.99': '29.99',
#  'MSG:29.100': '29.100',
#  'MSG:29.101': '29.101',
#  'MSG:29.102': '29.102',
#  'MSG:29.103': '29.103',
#  'MSG:29.104': '29.104',
#  'MSG:29.105': '29.105',
#  'MSG:29.106': '29.106',
#  'MSG:29.107': '29.107',
#  'MSG:29.108': '29.108',
#  'MSG:29.109': '29.109',
#  'MSG:29.110': '29.110',
#  'MSG:30.111': '30.111',
#  'MSG:30.112': '30.112',
#  'MSG:30.113': '30.113',
#  'MSG:30.114': '30.114',
#  'MSG:30.115': '30.115',
#  'MSG:30.116': '30.116',
#  'MSG:30.117': '30.117',
#  'MSG:30.118': '30.118',
#  'MSG:30.119': '30.119',
#  'MSG:30.120': '30.120',
#  'MSG:30.121': '30.121',
#  'MSG:30.122': '30.122',
#  'MSG:31.123': '31.123',
#  'MSG:31.124': '31.124',
#  'MSG:31.125': '31.125',
#  'MSG:31.126': '31.126',
#  'MSG:31.127': '31.127',
#  'MSG:31.128': '31.128',
#  'MSG:31.129': '31.129',
#  'MSG:31.130': '31.130',
#  'MSG:31.131': '31.131',
#  'MSG:31.132': '31.132',
#  'MSG:31.133': '31.133',
#  'MSG:31.134': '31.134',
#  'MSG:32.135': '32.135',
#  'MSG:32.136': '32.136',
#  'MSG:32.137': '32.137',
#  'MSG:32.138': '32.138',
#  'MSG:32.139': '32.139',
#  'MSG:32.140': '32.140',
#  'MSG:32.141': '32.141',
#  'MSG:32.142': '32.142',
#  'MSG:32.143': '32.143',
#  'MSG:33.144': '33.144',
#  'MSG:33.145': '33.145',
#  'MSG:33.146': '33.146',
#  'MSG:33.147': '33.147',
#  'MSG:33.148': '33.148',
#  'MSG:33.149': '33.149',
#  'MSG:33.150': '33.150',
#  'MSG:33.151': '33.151',
#  'MSG:33.152': '33.152',
#  'MSG:33.153': '33.153',
#  'MSG:33.154': '33.154',
#  'MSG:33.155': '33.155',
#  'MSG:34.156': '34.156',
#  'MSG:34.157': '34.157',
#  'MSG:34.158': '34.158',
#  'MSG:34.159': '34.159',
#  'MSG:34.160': '34.160',
#  'MSG:34.161': '34.161',
#  'MSG:34.162': '34.162',
#  'MSG:34.163': '34.163',
#  'MSG:34.164': '34.164',
#  'MSG:35.165': '35.165',
#  'MSG:35.166': '35.166',
#  'MSG:35.167': '35.167',
#  'MSG:35.168': '35.168',
#  'MSG:35.169': '35.169',
#  'MSG:35.170': '35.170',
#  'MSG:35.171': '35.171',
#  'MSG:36.172': '36.172',
#  'MSG:36.173': '36.173',
#  'MSG:36.174': '36.174',
#  'MSG:36.175': '36.175',
#  'MSG:36.176': '36.176',
#  'MSG:36.177': '36.177',
#  'MSG:36.178': '36.178',
#  'MSG:36.179': '36.179',
#  'MSG:37.180': '37.180',
#  'MSG:37.181': '37.181',
#  'MSG:37.182': '37.182',
#  'MSG:37.183': '37.183',
#  'MSG:37.184': '37.184',
#  'MSG:37.185': '37.185',
#  'MSG:37.186': '37.186',
#  'MSG:38.187': '38.187',
#  'MSG:38.188': '38.188',
#  'MSG:38.189': '38.189',
#  'MSG:38.190': '38.190',
#  'MSG:38.191': '38.191',
#  'MSG:38.192': '38.192',
#  'MSG:38.193': '38.193',
#  'MSG:38.194': '38.194',
#  'MSG:39.195': '39.195',
#  'MSG:39.196': '39.196',
#  'MSG:39.197': '39.197',
#  'MSG:39.198': '39.198',
#  'MSG:39.199': '39.199',
#  'MSG:39.200': '39.200',
#  'MSG:39.201': '39.201',
#  'MSG:39.202': '39.202',
#  'MSG:40.203': '40.203',
#  'MSG:40.204': '40.204',
#  'MSG:40.205': '40.205',
#  'MSG:40.206': '40.206',
#  'MSG:40.207': '40.207',
#  'MSG:40.208': '40.208',
#  'MSG:40.209': '40.209',
#  'MSG:40.210': '40.210',
#  'MSG:41.211': '41.211',
#  'MSG:41.212': '41.212',
#  'MSG:41.213': '41.213',
#  'MSG:41.214': '41.214',
#  'MSG:41.215': '41.215',
#  'MSG:41.216': '41.216',
#  'MSG:41.217': '41.217',
#  'MSG:41.218': '41.218',
#  'MSG:42.219': '42.219',
#  'MSG:42.220': '42.220',
#  'MSG:42.221': '42.221',
#  'MSG:42.222': '42.222',
#  'MSG:42.223': '42.223',
#  'MSG:43.224': '43.224',
#  'MSG:43.225': '43.225',
#  'MSG:43.226': '43.226',
#  'MSG:43.227': '43.227',
#  'MSG:43.228': '43.228',
#  'MSG:44.229': '44.229',
#  'MSG:44.230': '44.230',
#  'MSG:44.231': '44.231',
#  'MSG:44.232': '44.232',
#  'MSG:44.233': '44.233',
#  'MSG:44.234': '44.234',
#  'MSG:45.235': '45.235',
#  'MSG:45.236': '45.236',
#  'MSG:45.237': '45.237',
#  'MSG:45.238': '45.238',
#  'MSG:45.239': '45.239',
#  'MSG:45.240': '45.240',
#  'MSG:46.241': '46.241',
#  'MSG:46.242': '46.242',
#  'MSG:46.243': '46.243',
#  'MSG:46.244': '46.244',
#  'MSG:46.245': '46.245',
#  'MSG:46.246': '46.246',
#  'MSG:46.247': '46.247',
#  'MSG:46.248': '46.248',
#  'MSG:47.249': '47.249',
#  'MSG:47.250': '47.250',
#  'MSG:47.251': '47.251',
#  'MSG:47.252': '47.252',
#  'MSG:47.253': '47.253',
#  'MSG:47.254': '47.254',
#  'MSG:47.255': '47.255',
#  'MSG:47.256': '47.256',
#  'MSG:48.257': '48.257',
#  'MSG:48.258': '48.258',
#  'MSG:48.259': '48.259',
#  'MSG:48.260': '48.260',
#  'MSG:48.261': '48.261',
#  'MSG:48.262': '48.262',
#  'MSG:48.263': '48.263',
#  'MSG:48.264': '48.264',
#  'MSG:49.265': '49.265',
#  'MSG:49.266': '49.266',
#  'MSG:49.267': '49.267',
#  'MSG:49.268': '49.268',
#  'MSG:49.269': '49.269',
#  'MSG:49.270': '49.270',
#  'MSG:49.271': '49.271',
#  'MSG:49.272': '49.272',
#  'MSG:49.273': '49.273',
#  'MSG:49.274': '49.274',
#  'MSG:49.275': '49.275',
#  'MSG:49.276': '49.276',
#  'MSG:50.277': '50.277',
#  'MSG:50.278': '50.278',
#  'MSG:50.279': '50.279',
#  'MSG:50.280': '50.280',
#  'MSG:50.281': '50.281',
#  'MSG:50.282': '50.282',
#  'MSG:50.283': '50.283',
#  'MSG:50.284': '50.284',
#  'MSG:50.285': '50.285',
#  'MSG:50.286': '50.286',
#  'MSG:50.287': '50.287',
#  'MSG:50.288': '50.288',
#  'MSG:51.289': '51.289',
#  'MSG:51.290': '51.290',
#  'MSG:51.291': '51.291',
#  'MSG:51.292': '51.292',
#  'MSG:51.293': '51.293',
#  'MSG:51.294': '51.294',
#  'MSG:51.295': '51.295',
#  'MSG:51.296': '51.296',
#  'MSG:51.297': '51.297',
#  'MSG:51.298': '51.298',
#  'MSG:51.299': '51.299',
#  'MSG:51.300': '51.300',
#  'MSG:51.301': '51.301',
#  'MSG:51.302': '51.302',
#  'MSG:51.303': '51.303',
#  'MSG:51.304': '51.304',
#  'MSG:52.305': '52.305',
#  'MSG:52.306': '52.306',
#  'MSG:52.307': '52.307',
#  'MSG:52.308': '52.308',
#  'MSG:52.309': '52.309',
#  'MSG:52.310': '52.310',
#  'MSG:52.311': '52.311',
#  'MSG:52.312': '52.312',
#  'MSG:52.313': '52.313',
#  'MSG:52.314': '52.314',
#  'MSG:52.315': '52.315',
#  'MSG:52.316': '52.316',
#  'MSG:52.317': '52.317',
#  'MSG:52.318': '52.318',
#  'MSG:52.319': '52.319',
#  'MSG:52.320': '52.320',
#  'MSG:53.321': '53.321',
#  'MSG:53.322': '53.322',
#  'MSG:53.323': '53.323',
#  'MSG:53.324': '53.324',
#  'MSG:53.325': '53.325',
#  'MSG:53.326': '53.326',
#  'MSG:53.327': '53.327',
#  'MSG:53.328': '53.328',
#  'MSG:53.329': '53.329',
#  'MSG:53.330': '53.330',
#  'MSG:53.331': '53.331',
#  'MSG:53.332': '53.332',
#  'MSG:53.333': '53.333',
#  'MSG:53.334': '53.334',
#  'MSG:53.335': '53.335',
#  'MSG:53.336': '53.336',
#  'MSG:54.337': '54.337',
#  'MSG:54.338': '54.338',
#  'MSG:54.339': '54.339',
#  'MSG:54.340': '54.340',
#  'MSG:54.341': '54.341',
#  'MSG:54.342': '54.342',
#  'MSG:54.343': '54.343',
#  'MSG:54.344': '54.344',
#  'MSG:54.345': '54.345',
#  'MSG:54.346': '54.346',
#  'MSG:54.347': '54.347',
#  'MSG:54.348': '54.348',
#  'MSG:54.349': '54.349',
#  'MSG:54.350': '54.350',
#  'MSG:54.351': '54.351',
#  'MSG:54.352': '54.352',
#  'MSG:55.353': '55.353',
#  'MSG:55.354': '55.354',
#  'MSG:55.355': '55.355',
#  'MSG:55.356': '55.356',
#  'MSG:55.357': '55.357',
#  'MSG:55.358': '55.358',
#  'MSG:55.359': '55.359',
#  'MSG:55.360': '55.360',
#  'MSG:55.361': '55.361',
#  'MSG:55.362': '55.362',
#  'MSG:55.363': '55.363',
#  'MSG:55.364': '55.364',
#  'MSG:56.365': '56.365',
#  'MSG:56.366': '56.366',
#  'MSG:56.367': '56.367',
#  'MSG:56.368': '56.368',
#  'MSG:56.369': '56.369',
#  'MSG:56.370': '56.370',
#  'MSG:56.371': '56.371',
#  'MSG:56.372': '56.372',
#  'MSG:56.373': '56.373',
#  'MSG:56.374': '56.374',
#  'MSG:56.375': '56.375',
#  'MSG:56.376': '56.376',
#  'MSG:57.377': '57.377',
#  'MSG:57.378': '57.378',
#  'MSG:57.379': '57.379',
#  'MSG:57.380': '57.380',
#  'MSG:57.381': '57.381',
#  'MSG:57.382': '57.382',
#  'MSG:57.383': '57.383',
#  'MSG:57.384': '57.384',
#  'MSG:57.385': '57.385',
#  'MSG:57.386': '57.386',
#  'MSG:57.387': '57.387',
#  'MSG:57.388': '57.388',
#  'MSG:57.389': '57.389',
#  'MSG:57.390': '57.390',
#  'MSG:57.391': '57.391',
#  'MSG:57.392': '57.392',
#  'MSG:58.393': '58.393',
#  'MSG:58.394': '58.394',
#  'MSG:58.395': '58.395',
#  'MSG:58.396': '58.396',
#  'MSG:58.397': '58.397',
#  'MSG:58.398': '58.398',
#  'MSG:58.399': '58.399',
#  'MSG:58.400': '58.400',
#  'MSG:58.401': '58.401',
#  'MSG:58.402': '58.402',
#  'MSG:58.403': '58.403',
#  'MSG:58.404': '58.404',
#  'MSG:59.405': '59.405',
#  'MSG:59.406': '59.406',
#  'MSG:59.407': '59.407',
#  'MSG:59.408': '59.408',
#  'MSG:59.409': '59.409',
#  'MSG:59.410': '59.410',
#  'MSG:59.411': '59.411',
#  'MSG:59.412': '59.412',
#  'MSG:59.413': '59.413',
#  'MSG:59.414': '59.414',
#  'MSG:59.415': '59.415',
#  'MSG:59.416': '59.416',
#  'MSG:60.417': '60.417',
#  'MSG:60.418': '60.418',
#  'MSG:60.419': '60.419',
#  'MSG:60.420': '60.420',
#  'MSG:60.421': '60.421',
#  'MSG:60.422': '60.422',
#  'MSG:60.423': '60.423',
#  'MSG:60.424': '60.424',
#  'MSG:60.425': '60.425',
#  'MSG:60.426': '60.426',
#  'MSG:60.427': '60.427',
#  'MSG:60.428': '60.428',
#  'MSG:60.429': '60.429',
#  'MSG:60.430': '60.430',
#  'MSG:60.431': '60.431',
#  'MSG:60.432': '60.432',
#  'MSG:61.433': '61.433',
#  'MSG:61.434': '61.434',
#  'MSG:61.435': '61.435',
#  'MSG:61.436': '61.436',
#  'MSG:61.437': '61.437',
#  'MSG:61.438': '61.438',
#  'MSG:61.439': '61.439',
#  'MSG:61.440': '61.440',
#  'MSG:62.441': '62.441',
#  'MSG:62.442': '62.442',
#  'MSG:62.443': '62.443',
#  'MSG:62.444': '62.444',
#  'MSG:62.445': '62.445',
#  'MSG:62.446': '62.446',
#  'MSG:62.447': '62.447',
#  'MSG:62.448': '62.448',
#  'MSG:62.449': '62.449',
#  'MSG:62.450': '62.450',
#  'MSG:62.451': '62.451',
#  'MSG:62.452': '62.452',
#  'MSG:62.453': '62.453',
#  'MSG:62.454': '62.454',
#  'MSG:62.455': '62.455',
#  'MSG:62.456': '62.456',
#  'MSG:63.457': '63.457',
#  'MSG:63.458': '63.458',
#  'MSG:63.459': '63.459',
#  'MSG:63.460': '63.460',
#  'MSG:63.461': '63.461',
#  'MSG:63.462': '63.462',
#  'MSG:63.463': '63.463',
#  'MSG:63.464': '63.464',
#  'MSG:63.465': '63.465',
#  'MSG:63.466': '63.466',
#  'MSG:63.467': '63.467',
#  'MSG:63.468': '63.468',
#  ...}
