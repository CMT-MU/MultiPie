# %%
"""
Check for so_matrix binary.
"""
from multipie.util.util_binary import BinaryManager
from multipie.core.multipie_info import __top_dir__
BIN_DIR = __top_dir__ + "others/tools/binary_data"
so_matrix = BinaryManager("symmetry_operation_matrix", verbose=True, topdir=BIN_DIR)
# Out:
# load binary from '/Users/hk/Library/CloudStorage/Dropbox/working/GitHub/MultiPie2/others/tools/binary_data/symmetry_operation_matrix.pkl'.
# """
# * SO matrix of multipole in lm basis for cubic and hexagonal subgroups.
# - "cubic/hexagonal" (str): (Dict) polar (Q) or axial (G) SO matrix.
#   - (X,l) (str,int): (dict) SO matrix data.
#     - SO_tag (str): (ndarray(2l+1,2l+1,sympy)) SO matrix.
# """

# %%
so_matrix.keys()
# Out:
# dict_keys(['cubic', 'hexagonal'])

# %%
for tag, m in so_matrix["cubic"][("Q",1)].items():
    print(tag, m.tolist())
# Out:
# 1 [[1, 0, 0], [0, 1, 0], [0, 0, 1]]
# 2[001] [[-1, 0, 0], [0, 1, 0], [0, 0, -1]]
# 2[010] [[0, 0, 1], [0, -1, 0], [1, 0, 0]]
# 2[100] [[0, 0, -1], [0, -1, 0], [-1, 0, 0]]
# 3+[111] [[-I/2, -sqrt(2)/2, I/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [-I/2, sqrt(2)/2, I/2]]
# 3+[-11-1] [[I/2, -sqrt(2)/2, -I/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [I/2, sqrt(2)/2, -I/2]]
# 3+[1-1-1] [[I/2, sqrt(2)/2, -I/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [I/2, -sqrt(2)/2, -I/2]]
# 3+[-1-11] [[-I/2, sqrt(2)/2, I/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [-I/2, -sqrt(2)/2, I/2]]
# 3-[111] [[I/2, sqrt(2)*I/2, I/2], [-sqrt(2)/2, 0, sqrt(2)/2], [-I/2, sqrt(2)*I/2, -I/2]]
# 3-[1-1-1] [[-I/2, sqrt(2)*I/2, -I/2], [sqrt(2)/2, 0, -sqrt(2)/2], [I/2, sqrt(2)*I/2, I/2]]
# 3-[-1-11] [[I/2, -sqrt(2)*I/2, I/2], [sqrt(2)/2, 0, -sqrt(2)/2], [-I/2, -sqrt(2)*I/2, -I/2]]
# 3-[-11-1] [[-I/2, -sqrt(2)*I/2, -I/2], [-sqrt(2)/2, 0, sqrt(2)/2], [I/2, -sqrt(2)*I/2, I/2]]
# 2[110] [[0, 0, I], [0, -1, 0], [-I, 0, 0]]
# 2[1-10] [[0, 0, -I], [0, -1, 0], [I, 0, 0]]
# 4-[001] [[I, 0, 0], [0, 1, 0], [0, 0, -I]]
# 4+[001] [[-I, 0, 0], [0, 1, 0], [0, 0, I]]
# 4-[100] [[1/2, sqrt(2)*I/2, -1/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [-1/2, sqrt(2)*I/2, 1/2]]
# 2[011] [[-1/2, sqrt(2)*I/2, 1/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [1/2, sqrt(2)*I/2, -1/2]]
# 2[01-1] [[-1/2, -sqrt(2)*I/2, 1/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [1/2, -sqrt(2)*I/2, -1/2]]
# 4+[100] [[1/2, -sqrt(2)*I/2, -1/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [-1/2, -sqrt(2)*I/2, 1/2]]
# 4+[010] [[1/2, -sqrt(2)/2, 1/2], [sqrt(2)/2, 0, -sqrt(2)/2], [1/2, sqrt(2)/2, 1/2]]
# 2[101] [[-1/2, -sqrt(2)/2, -1/2], [-sqrt(2)/2, 0, sqrt(2)/2], [-1/2, sqrt(2)/2, -1/2]]
# 4-[010] [[1/2, sqrt(2)/2, 1/2], [-sqrt(2)/2, 0, sqrt(2)/2], [1/2, -sqrt(2)/2, 1/2]]
# 2[-101] [[-1/2, sqrt(2)/2, -1/2], [sqrt(2)/2, 0, -sqrt(2)/2], [-1/2, -sqrt(2)/2, -1/2]]
# -1 [[-1, 0, 0], [0, -1, 0], [0, 0, -1]]
# m[001] [[1, 0, 0], [0, -1, 0], [0, 0, 1]]
# m[010] [[0, 0, -1], [0, 1, 0], [-1, 0, 0]]
# m[100] [[0, 0, 1], [0, 1, 0], [1, 0, 0]]
# -3+[111] [[I/2, sqrt(2)/2, -I/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [I/2, -sqrt(2)/2, -I/2]]
# -3+[-11-1] [[-I/2, sqrt(2)/2, I/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [-I/2, -sqrt(2)/2, I/2]]
# -3+[1-1-1] [[-I/2, -sqrt(2)/2, I/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [-I/2, sqrt(2)/2, I/2]]
# -3+[-1-11] [[I/2, -sqrt(2)/2, -I/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [I/2, sqrt(2)/2, -I/2]]
# -3-[111] [[-I/2, -sqrt(2)*I/2, -I/2], [sqrt(2)/2, 0, -sqrt(2)/2], [I/2, -sqrt(2)*I/2, I/2]]
# -3-[1-1-1] [[I/2, -sqrt(2)*I/2, I/2], [-sqrt(2)/2, 0, sqrt(2)/2], [-I/2, -sqrt(2)*I/2, -I/2]]
# -3-[-1-11] [[-I/2, sqrt(2)*I/2, -I/2], [-sqrt(2)/2, 0, sqrt(2)/2], [I/2, sqrt(2)*I/2, I/2]]
# -3-[-11-1] [[I/2, sqrt(2)*I/2, I/2], [sqrt(2)/2, 0, -sqrt(2)/2], [-I/2, sqrt(2)*I/2, -I/2]]
# m[110] [[0, 0, -I], [0, 1, 0], [I, 0, 0]]
# m[1-10] [[0, 0, I], [0, 1, 0], [-I, 0, 0]]
# -4-[001] [[-I, 0, 0], [0, -1, 0], [0, 0, I]]
# -4+[001] [[I, 0, 0], [0, -1, 0], [0, 0, -I]]
# -4-[100] [[-1/2, -sqrt(2)*I/2, 1/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [1/2, -sqrt(2)*I/2, -1/2]]
# m[011] [[1/2, -sqrt(2)*I/2, -1/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [-1/2, -sqrt(2)*I/2, 1/2]]
# m[01-1] [[1/2, sqrt(2)*I/2, -1/2], [-sqrt(2)*I/2, 0, -sqrt(2)*I/2], [-1/2, sqrt(2)*I/2, 1/2]]
# -4+[100] [[-1/2, sqrt(2)*I/2, 1/2], [sqrt(2)*I/2, 0, sqrt(2)*I/2], [1/2, sqrt(2)*I/2, -1/2]]
# -4+[010] [[-1/2, sqrt(2)/2, -1/2], [-sqrt(2)/2, 0, sqrt(2)/2], [-1/2, -sqrt(2)/2, -1/2]]
# m[101] [[1/2, sqrt(2)/2, 1/2], [sqrt(2)/2, 0, -sqrt(2)/2], [1/2, -sqrt(2)/2, 1/2]]
# -4-[010] [[-1/2, -sqrt(2)/2, -1/2], [sqrt(2)/2, 0, -sqrt(2)/2], [-1/2, sqrt(2)/2, -1/2]]
# m[-101] [[1/2, -sqrt(2)/2, 1/2], [-sqrt(2)/2, 0, sqrt(2)/2], [1/2, sqrt(2)/2, 1/2]]
