# %%
"""
Check for util_symmetry_operation_spherical.py.
"""
import numpy as np

from qtdraw import QtDraw

from utils.util_symmetry_operation_spherical import representation_matrix
from utils.util_plot import plot_harmonics

qtdraw = QtDraw()
qtdraw.set_cell("off")

# %%
l, s, k = 2, 0, 0
du = np.array([0, 0, 1, 0, 0])
g = representation_matrix(2, 3, [1, 1, 1], tesseral=False)
dup = g @ du
plot_harmonics(qtdraw, l, s, k, v=du)

# %%
plot_harmonics(qtdraw, l, s, k, v=dup)
